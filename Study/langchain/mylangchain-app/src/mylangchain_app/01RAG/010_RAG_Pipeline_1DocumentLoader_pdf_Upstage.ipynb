# %% [markdown]
# ### 1) 라이브러리 설치

# %%
# poetry add pypdf=">=4.2.0,<5.0.0"
# poetry add langchain-upstage
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### PyPDFLoader 간단한 예제

# %%
from dotenv import load_dotenv
import os

# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

UPSTAGE_API_KEY = os.getenv("UPSTAGE_API_KEY")
print(UPSTAGE_API_KEY[30:])
# Out:
# x4

# %% [markdown]
# #### Upstage 를 사용한 RAG
# * ChatUpstage
# * UpstageEmbeddings
# * UpstageDocumentParseLoader

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_upstage import ChatUpstage
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain_upstage import UpstageEmbeddings

print("==> 1. 문서 로딩 → PDF 읽기...")
file_path = "../data/tutorial-korean.pdf"
loader = PyPDFLoader('../data/tutorial-korean.pdf')
documents = loader.load()
print(f"  총 {len(documents)}페이지 로드 완료")
# Out:
# ==> 1. 문서 로딩 → PDF 읽기...
#   총 39페이지 로드 완료

# %%
print("==> 2. 문서 분할 → 작은 청크로 나누기")
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,        # 청크 크기 (한국어 최적화)
    chunk_overlap=200,      # 중복 부분 (맥락 보존)
    separators=["\n\n", "\n", ".", " ", ""] # 자연스러운 분할을 위한 구분자
)

chunks = text_splitter.split_documents(documents)
print(f"  {len(chunks)}개 청크 생성 완료")
print(f"  평균 청크 길이: {sum(len(chunk.page_content) for chunk in chunks) / len(chunks):.0f}자")

print("==> 3. 벡터화 → 임베딩으로 변환")
embeddings = UpstageEmbeddings(model="solar-embedding-1-large")

print("==> 4. 저장 → FAISS 벡터스토어에 저장")
vectorstore = FAISS.from_documents(chunks, embeddings)
print(f" FAISS 벡터스토어 생성 완료 ({len(chunks)}개 벡터)")
# 로컬 파일로 저장
vectorstore.save_local("faiss_index_upstage")

print("===> 5. 검색 → 질문과 유사한 문서 찾기")
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 6}  # 상위 6개 관련 문서 검색
)
print(" Retriever 설정 완료")
# Out:
# ==> 2. 문서 분할 → 작은 청크로 나누기
#   66개 청크 생성 완료
#   평균 청크 길이: 688자
# ==> 3. 벡터화 → 임베딩으로 변환
# ==> 4. 저장 → FAISS 벡터스토어에 저장
#  FAISS 벡터스토어 생성 완료 (66개 벡터)
# ===> 5. 검색 → 질문과 유사한 문서 찾기
#  Retriever 설정 완료

# %%
print("===> 6. 생성 → LLM으로 답변 생성")
llm = ChatUpstage(
        model="solar-pro",
        base_url="https://api.upstage.ai/v1",
        temperature=0.5
    )
print(llm)
# Out:
# ===> 6. 생성 → LLM으로 답변 생성
# client=<openai.resources.chat.completions.completions.Completions object at 0x115a7dbe0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x115a7de80> model_name='solar-pro' temperature=0.5 model_kwargs={} upstage_api_key=SecretStr('**********') upstage_api_base='https://api.upstage.ai/v1'

# %%
# 한국어 최적화 프롬프트
prompt_template = """
당신은 BlueJ 프로그래밍 환경 전문가입니다. 
아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.

문서 내용:
{context}

질문: {question}

답변 규칙:
1. 문서 내용만을 근거로 답변하세요
2. 단계별 설명이 필요하면 순서대로 작성하세요  
3. 구체적인 메뉴명, 버튼명을 포함하세요
4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요

답변:"""

prompt = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"]
)
print(" 프롬프트 설정 완료")
print(prompt)
# Out:
#  프롬프트 설정 완료
# input_variables=['context', 'question'] input_types={} partial_variables={} template='\n당신은 BlueJ 프로그래밍 환경 전문가입니다. \n아래 문서 내용을 바탕으로 정확하고 친절한 답변을 제공해주세요.\n\n문서 내용:\n{context}\n\n질문: {question}\n\n답변 규칙:\n1. 문서 내용만을 근거로 답변하세요\n2. 단계별 설명이 필요하면 순서대로 작성하세요  \n3. 구체적인 메뉴명, 버튼명을 포함하세요\n4. 문서에 없는 정보는 "문서에서 찾을 수 없습니다"라고 하세요\n\n답변:'

# %%
# ===================================
# 7. QA 체인 생성
# ===================================
print("\n ===> 7.  QA 체인 생성...")
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    chain_type_kwargs={"prompt": prompt},
    return_source_documents=True
)
print("  RAG 파이프라인 구축 완료!")

# ===================================
# 8. 테스트 질문들
# ===================================
test_questions = [
    "BlueJ에서 객체를 생성하는 방법은 무엇인가요?",
    "컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?", 
    "디버깅을 위해 중단점을 설정하는 방법을 알려주세요",
    "코드패드는 무엇이고 어떻게 사용하나요?",
    "애플릿을 만들고 실행하는 방법을 설명해주세요"
]

print("\n" + "=" * 60)
print(" RAG 시스템 테스트")
print("=" * 60)

# ===================================
# 9. 질문 및 답변 실행
# ===================================
for i, question in enumerate(test_questions, 1):
    print(f"\n【테스트 {i}/5】")
    print(f" 질문: {question}")
    print(" 답변 생성 중...")
    
    # RAG 실행
    result = qa_chain.invoke({"query": question})
    answer = result["result"]
    source_docs = result["source_documents"]
    
    print(f"\n 답변:")
    print("-" * 50)
    print(answer)
    
    # 참조 문서 정보
    print(f"\n 참조 문서:")
    for j, doc in enumerate(source_docs[:3], 1):
        page = doc.metadata.get('page', 'N/A')
        preview = doc.page_content[:80].replace('\n', ' ')
        print(f"   {j}. 페이지 {page}: {preview}...")
    
    print("\n" + "-" * 40)
# Out:
#  ===> 7.  QA 체인 생성...
#   RAG 파이프라인 구축 완료!
#
# ============================================================
#  RAG 시스템 테스트
# ============================================================
#
# 【테스트 1/5】
#  질문: BlueJ에서 객체를 생성하는 방법은 무엇인가요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# BlueJ에서 객체를 생성하는 방법은 다음과 같습니다. 문서 내용을 근거로 단계별로 설명드리겠습니다.
#
# ---
#
# ### **1. 일반 클래스로부터 객체 생성 방법**
# 1. **프로젝트 열기**
#    - BlueJ 시작 후 `Project - Open...` 메뉴를 선택해 프로젝트를 엽니다.
#    *(예: `examples/people` 프로젝트)*
#
# 2. **클래스 아이콘 확인**
#    - 메인 윈도우 중앙에 표시된 클래스 아이콘(예: `Person`, `Staff`)을 찾습니다.
#
# 3. **팝업 메뉴 호출**
#    - 생성할 클래스의 아이콘을 **마우스 오른쪽 버튼으로 클릭**합니다.
#    (맥OS: `Ctrl + 클릭`)
#
# 4. **생성자 선택**
#    - 팝업 메뉴에서 `new [클래스명](...)` 형식의 생성자를 선택합니다.
#    *(예: `new Staff()`)*
#
# 5. **객체 이름 입력**
#    - 대화상자에서 객체 이름을 입력하거나 기본 이름(예: `staff1`)을 그대로 사용합니다.
#    - `OK` 버튼을 클릭하면 객체가 생성됩니다.
#
# 6. **객체 확인**
#    - 생성된 객체는 **오브젝트 벤치(Object Bench)**에 표시됩니다.
#    *(추상 클래스(`<<abstract>>` 표기)는 객체 생성 불가능)*
#
# ---
#
# ### **2. 라이브러리 클래스로부터 객체 생성 방법**
# 1. **메뉴 선택**
#    - 상단 메뉴에서 `Tools - Use Libraries Class`를 선택합니다.
#
# 2. **클래스명 입력**
#    - 대화상자에 **패키지 이름 포함**된 완전한 클래스명(예: `java.lang.String`)을 입력합니다.
#    - 최근 사용 기록이 텍스트 필드에 표시될 수 있습니다.
#
# 3. **생성자/정적 메소드 선택**
#    - 엔터 키를 누르면 해당 클래스의 생성자 및 정적 메소드 목록이 표시됩니다.
#    - 원하는 생성자 또는 메소드를 선택해 호출합니다.
#
# ---
#
# ### **요약**
# - **일반 클래스**: 클래스 아이콘 우클릭 → 생성자 선택 → 이름 입력 → 객체 생성
# - **라이브러리 클래스**: `Tools - Use Libraries Class` → 클래스명 입력 → 생성자/메소드 호출
#
# 문서에서 찾을 수 없는 추가 정보는 생략되었습니다.
#
#  참조 문서:
#    1. 페이지 1: 3.1. BlueJ 시작하기 ············································· ··················...
#    2. 페이지 35: 3610.6. 라이브러리 클래스로부터 객체생성하기 BlueJ 는 JDK에서 제공하는 라이브러리의 클래스들로부터 객체를 생성하기 위한 기능을  제...
#    3. 페이지 7: 83.2. 프로젝트 열기 프로젝트란, 관련 있는 여러개의 파일들을 묶어서 관리하기 위한 하나의 작업 단위를 말합니다.  BlueJ  프로젝트는 ...
#
# ----------------------------------------
#
# 【테스트 2/5】
#  질문: 컴파일 오류가 발생했을 때 어떻게 확인할 수 있나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# BlueJ에서 컴파일 오류를 확인하는 방법은 다음과 같습니다.
#
# ### 1. **에디터 창에서 직접 확인**
#    - 오류가 발생한 클래스는 자동으로 에디터가 열리며, **에러가 발생한 코드 라인이 반전되어 표시됩니다**.
#    - 에디터 하단의 **정보창(Information Area)**에 구체적인 오류 메시지가 출력됩니다.
#
# ### 2. **도움말 버튼 활용**
#    - 정보창에 표시된 오류 메시지 오른쪽의 **물음표(?) 버튼**을 클릭하면, 해당 오류에 대한 추가 설명을 확인할 수 있습니다(문서 그림 8 참조).
#    - *단, 모든 오류에 도움말이 제공되지는 않습니다.*
#
# ### 3. **프로젝트 툴바에서 전체 컴파일 시 오류 확인**
#    - 프로젝트 창의 툴바에서 **Compile 버튼**을 눌러 전체 프로젝트를 컴파일할 경우:
#      - 오류가 있는 클래스는 자동으로 에디터가 열리며, 위와 동일한 방식으로 오류 위치를 표시합니다.
#    - 수정된 클래스는 아이콘에 **체크 표시(✓)**가 나타나며, Compile 버튼으로 재컴파일할 수 있습니다.
#
# ### 4. **오브젝트 벤치 초기화 주의**
#    - 컴파일 오류 발생 시 **오브젝트 벤치의 기존 객체는 자동으로 삭제**됩니다. 클래스 수정 후 재컴파일이 필요합니다.
#
# ### 5. **저장 관련 참고 사항**
#    - 소스 코드는 컴파일 시 또는 에디터 닫을 때 **자동 저장**되지만, 시스템 불안정이 우려될 경우 **Class 메뉴**에서 수동으로 저장할 수 있습니다.
#
# > 문서에는 "세미콜론 누락"과 같은 구문 오류를 의도적으로 생성해 확인하는 방법도 제안되어 있습니다(3.6절 참조).
#
# ---
# **문서에서 찾을 수 없는 정보**:
# - 특정 오류 코드의 상세 설명 (예: "cannot find symbol")
# - 오류 로그 파일 위치 또는 외부 도구 연동 방법
#
#  참조 문서:
#    1. 페이지 12: 클래스를 성공적으로 컴파일 하였다면 에디터를 닫으십시오.  프로젝트 윈도우에 툴바 역시 Compile 버튼을 가지고 있습니다. 이 컴파일 기능은...
#    2. 페이지 12: 13  노트 : 프로젝트를 처음 열었을 때 왜 클래스 아이콘에 체크표시가 되어있지 않은지 궁금할 수 있습니다. people  프로젝트 내의 클래...
#    3. 페이지 1: 3.1. BlueJ 시작하기 ············································· ··················...
#
# ----------------------------------------
#
# 【테스트 3/5】
#  질문: 디버깅을 위해 중단점을 설정하는 방법을 알려주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### 디버깅을 위해 중단점을 설정하는 방법 (BlueJ 기준)
#
# 1. **프로젝트 준비**
#    - `examples` 디렉토리에 포함된 `debugdemo` 프로젝트를 엽니다.
#    - `Demo` 클래스를 열고, `loop` 메소드를 찾습니다.
#
# 2. **중단점 설정 위치 선택**
#    - `loop` 메소드 내 `for` 반복문 중 임의의 라인을 선택합니다.
#    - (예: `sum += i;` 또는 반복문 조건문 라인)
#
# 3. **중단점 설정 방법**
#    - 편집기 창에서 소스코드의 **왼쪽 여백(회색 영역)** 을 마우스 **왼쪽 버튼으로 클릭**합니다.
#    - 클릭 시 작은 **정지(Stop) 표시** 가 나타나며, 이는 중단점이 설정되었음을 의미합니다.
#      *(참고: 그림 13에서 중단점 영역을 시각적으로 확인할 수 있습니다.)*
#
# 4. **중단점 확인 및 실행**
#    - `Demo` 클래스에서 객체를 생성한 후, `loop` 메소드를 `10`을 매개변수로 호출합니다.
#    - 프로그램 실행이 중단점에 도달하면:
#      - 편집기에서 **다음 실행할 라인이 반전 표시** 됩니다.
#      - **디버거 윈도우** 가 자동으로 열리며 실행 상태를 확인할 수 있습니다.
#      *(참고: 그림 14 참조)*
#
# 5. **중단점 제거**
#    - 중단점을 제거하려면 동일한 영역을 다시 **마우스 왼쪽 버튼으로 클릭** 합니다.
#    - 정지 표시가 사라지며 중단점이 해제됩니다.
#
# > ✅ **요약**:
# > 중단점 영역(소스코드 왼쪽 여백) 클릭 → 정지 표시 확인 → 프로그램 실행 시 해당 위치에서 일시 정지 → 디버거 윈도우로 상태 분석 가능.
# > (문서 26~27페이지, 37페이지 21번 항목 참조)
#
#  참조 문서:
#    1. 페이지 25: 267. 디버깅 이 절에서는, BlueJ의 디버깅에 관한 기능들 중에서 가장 중요한 측면을 소개합니다. 컴퓨터  프로그래밍 담당 선생님들은 첫 ...
#    2. 페이지 2: 37. 디버깅 ························································· ··············...
#    3. 페이지 25: 마우스 왼쪽 버튼으로 클릭함으로써 중단점을 설정할 수 있습니다. 작은 stop 표시가 중단점을 의미합니다. 바로 시도해 봅시다. Demo  클래...
#
# ----------------------------------------
#
# 【테스트 4/5】
#  질문: 코드패드는 무엇이고 어떻게 사용하나요?
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# **코드패드란?**
# BlueJ 코드패드는 자바 코드(표현식 및 명령문)의 일부를 실시간으로 평가하고 테스트할 수 있는 도구입니다. 프로그램 로직의 의미를 조사하거나 구문을 시험할 때 유용하며, 결과를 즉시 확인할 수 있습니다.
#
# ---
#
# ### **코드패드 사용 방법 (단계별 설명)**
#
# #### **1. 코드패드 표시하기**
# - **메뉴 경로**: `보기` → `코드패드 보기(Show Code Pad)` 선택
# - **위치**: BlueJ 메인 화면의 오른쪽 아래(오브젝트 벤치 옆)에 표시됩니다.
# - **크기 조절**: 코드패드와 오브젝트 벤치 사이의 가로/세로 선을 드래그하여 조절 가능합니다.
#
# #### **2. 표현식 평가하기**
# - **입력 방법**: 코드패드 영역에 간단한 표현식을 입력합니다.
#   - 예시:
#     ```java
#     4 + 45
#     "hello".length()
#     Math.max(33, 4)
#     new Student()  // 사용자 정의 클래스 객체 생성
#     ```
# - **실행**: 키보드 `Enter` 키를 눌러 라인 단위로 평가합니다.
# - **결과**: 결과값과 타입이 괄호 안에 표시되며, 객체일 경우 작은 아이콘이 함께 나타납니다.
#
# #### **3. 명령문 실행하기**
# - **단일 명령문**:
#   ```java
#   System.out.println("Hello");
#   ```
# - **멀티라인 명령문**:
#   - 각 라인 끝에 `Shift-Enter`를 눌러 줄 바꿈을 유지합니다.
#   - 예시:
#     ```java
#     int sum = 0;
#     sum += 5;
#     System.out.println(sum);  // Shift-Enter로 줄 구분
#     ```
# - **주의**: 지역 변수는 동일 라인 내에서만 유효합니다. 다른 라인에서 참조할 수 없습니다.
#
# #### **4. 객체를 오브젝트 벤치로 이동**
# - **방법**: 코드패드 결과 창의 객체 아이콘을 드래그하여 오브젝트 벤치로 이동합니다.
# - **목적**: 이후 메소드 호출이나 상태 검사에 활용할 수 있습니다.
#
# #### **5. 객체 검사하기**
# - **방법**: 코드패드에 표시된 객체 아이콘을 **더블클릭**합니다.
# - **기능**: 객체의 필드와 메소드 정보를 확인할 수 있는 "객체 상태 검사" 화면이 열립니다.
#
# #### **6. 사용자 입력 이력 활용**
# - **상하 화살표 키**: 이전에 입력한 코드를 재사용하거나 수정할 수 있습니다.
#
# ---
#
# ### **주의사항**
# - 코드패드에서 생성한 객체에 **새로운 인스턴스 필드를 추가할 수 없습니다**.
# - 오브젝트 벤치의 객체는 코드패드에서 인스턴스 필드처럼 참조 가능합니다.
# - 잘못된 표현식 입력 시 에러 메시지가 출력됩니다.
#
# ---
#
# ### **요약**
# 코드패드는 BlueJ의 강력한 테스트 도구로, **표현식 평가**, **명령문 실행**, **객체 생성 및 검사**를 실시간으로 수행할 수 있습니다. `Shift-Enter`로 멀티라인 입력을 지원하고, 객체 아이콘을 드래그하거나 더블클릭하여 추가 작업을 할 수 있습니다.
#
#  참조 문서:
#    1. 페이지 1: 5.2. 클래스 만들기 ················································ ··················...
#    2. 페이지 20: 216. 코드패드의 사용 BlueJ 코드패드는 자바 코드(표현식과 명령문)의 일부분을 쉽고 빠르게 평가할 수 있는 기능을  제공합니다. 따라서,...
#    3. 페이지 36: 15. 코드패드로부터 객체를 오브젝트 벤치로 이동하기 위해서는 객체아이콘을 드래그 하십시오. 16. 코드패드에서 생성된 객체를 검사하기 위해서는...
#
# ----------------------------------------
#
# 【테스트 5/5】
#  질문: 애플릿을 만들고 실행하는 방법을 설명해주세요
#  답변 생성 중...
#
#  답변:
# --------------------------------------------------
# ### 애플릿을 만들고 실행하는 방법 (BlueJ 기준)
#
# #### 1. **애플릿 만들기**
# 1. **새 클래스 생성**
#    - BlueJ 메인 창에서 **"New Class"** 버튼을 클릭합니다.
#    - 대화상자에서 클래스 이름을 입력한 후, **"Type"** 드롭다운 메뉴에서 **"Applet"**을 선택합니다.
#    - **"OK"**를 클릭하여 애플릿 클래스를 생성합니다.
#    - 생성된 클래스는 아이콘에 `<<applet>>` 태그가 표시됩니다.
#
# 2. **코드 작성**
#    - 생성된 클래스는 기본 골격 코드를 포함합니다.
#    - 에디터를 열어 `paint()` 메소드에 애플릿의 그래픽 코드를 작성합니다.
#      (예: `g.drawString("Hello", 20, 20);`)
#
# 3. **컴파일**
#    - 클래스 아이콘에서 마우스 오른쪽 버튼을 클릭 후 **"Compile"**을 선택하거나, 툴바의 **"Compile"** 버튼을 클릭합니다.
#
# ---
#
# #### 2. **애플릿 실행하기**
# 1. **Run Applet 실행**
#    - 컴파일된 애플릿 클래스의 팝업 메뉴에서 **"Run Applet"**을 선택합니다.
#    - 실행 옵션 대화상자가 나타납니다:
#      - **애플릿 뷰어**에서 실행 (JDK 내장 도구, 버전 호환성 우수)
#      - **웹 브라우저**에서 실행 (기본 브라우저 사용, Windows/MacOS)
#      - **HTML 파일만 생성** (Unix 시스템의 경우 설정 파일에서 브라우저 지정 필요)
#    - 옵션을 선택한 후 **"OK"**를 클릭하면 애플릿이 실행됩니다.
#
# 2. **테스트 방법**
#    - 애플릿 객체를 **"Object Bench"**에 생성해 일부 메소드를 테스트할 수 있습니다.
#    - 단, 전체 애플릿은 브라우저 또는 애플릿 뷰어에서만 완전히 실행됩니다.
#
# ---
#
# #### 3. **디버깅 방법**
# - **일반 디버깅 제한 사항**
#   - 브라우저/애플릿 뷰어에서 실행 시 BlueJ의 중단점(디버깅)이 적용되지 않습니다.
#     (각 환경마다 별도의 JVM을 사용하기 때문)
#
# - **대안: AppletWindow 클래스 사용**
#   - Michael Trigoboff의 **"AppletWindow"** 클래스를 BlueJ 프로젝트에 추가합니다.
#     - 이 클래스는 BlueJ 환경에서 애플릿을 직접 실행시켜 디버깅(중단점, Step 실행 등)을 가능하게 합니다.
#   - 다운로드 위치: BlueJ 공식 홈페이지의 **"Resources"** 메뉴에서 입수 가능.
#
# ---
#
# #### 4. **예시 프로젝트 참고**
# - **"examples/appletdemo"** 프로젝트를 열어 `CaseConverter` 애플릿을 실행해 볼 수 있습니다.
# - 실행 후 팝업 메뉴에서 **"Run Applet"**을 선택하면 애플릿 뷰어 또는 브라우저에서 확인할 수 있습니다.
#
# ---
#
# ### 주의사항
# - 문서에 명시되지 않은 기능(예: 특정 브라우저 호환성 문제)은 **"문서에서 찾을 수 없습니다"**로 답변합니다.
# - Unix 시스템의 브라우저 설정은 BlueJ 설정 파일에서 직접 수정해야 합니다.
#
#  참조 문서:
#    1. 페이지 32: 33마이크로소프트 윈도우즈나 MAC OS시스템에서, BlueJ 는 여러분의 기본 브라우저를 사용 합니다. 유닉스 시스템의 경우는, BlueJ 설...
#    2. 페이지 31: 329. 애플릿 만들기 9.1. 애플릿 실행하기     BuleJ 는 어플리케이션 뿐만 아니라 애플릿을 만들고, 실행할 수 있습니다. 예제(ex...
#    3. 페이지 2: 8. 독립형 어플리케이션 생성 ··············································· ···············...
#
# ----------------------------------------

# %%
from langchain_upstage import UpstageGroundednessCheck

groundedness_check = UpstageGroundednessCheck()

question = "BlueJ에서 객체를 생성하는 방법은 무엇인가요?"

retrieved_docs = retriever.invoke(question)
context = "\n\n".join([doc.page_content for doc in retrieved_docs])
#print(context)

response = llm.invoke(f"{question} 관련 정보: {context}")

request_input = {
    "context": context,
    "answer": response.content
}

response = groundedness_check.invoke(request_input)
print(response)
# Out:
# grounded
