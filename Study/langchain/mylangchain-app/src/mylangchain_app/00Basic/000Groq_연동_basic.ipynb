# %%
print("Hello LangChain")
# Out:
# Hello LangChain

# %%
import os
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI 

# load_dotenv(dotenv_path='.env')
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:9])
# Out:
# gsk_RXvlq

# %%
# prompt + llm + output 

# prompt
prompt = ChatPromptTemplate.from_messages(
    [ ("system", "당신은 개발자입니다.") , 
     ("user", "{input}") ]
)

print(type(prompt))
print(prompt)
# Out:
# <class 'langchain_core.prompts.chat.ChatPromptTemplate'>
# input_variables=['input'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 개발자입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]

# %%
prompt_text = prompt.format(input="파이썬은 무엇인가요? 자세하게 설명해주세요")
print(type(prompt_text))
print(prompt_text)
# Out:
# <class 'str'>
# System: 당신은 개발자입니다.
# Human: 파이썬은 무엇인가요? 자세하게 설명해주세요

# %%
#llm = ChatOpenAI(api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-0125")

# Groq API를 사용하는 ChatOpenAI 인스턴스 생성
llm = ChatOpenAI(
    # api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    # model="meta-llama/llama-4-scout-17b-16e-instruct",
    # model="moonshotai/kimi-k2-instruct-0905",
    model="openai/gpt-oss-120b",
    temperature=0.7
)
print(type(llm))
print(llm)
# Out:
# <class 'langchain_openai.chat_models.base.ChatOpenAI'>
# client=<openai.resources.chat.completions.completions.Completions object at 0x10b9f9a70> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x10b9f9e00> root_client=<openai.OpenAI object at 0x10b9f9810> root_async_client=<openai.AsyncOpenAI object at 0x10b9f9ba0> model_name='openai/gpt-oss-120b' temperature=0.7 model_kwargs={} openai_api_key=SecretStr('**********') openai_api_base='https://api.groq.com/openai/v1'

# %%
try:
    response = llm.invoke(prompt_text)
    print(type(response))
    print("응답:", response.content)
except Exception as e:
    print(f"오류 발생: {e}")
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 응답: ## 파이썬(Python)이란?
#
# 파이썬은 **범용 프로그래밍 언어**로, 1991년 네덜란드의 프로그래머 **귀도 반 로썸(Guido van Rossum)**이 발표했습니다. 현재는 전 세계 수많은 개발자와 기업이 사용하고 있으며, **오픈 소스**로 배포되어 누구나 자유롭게 사용·배포·수정할 수 있습니다.
#
# ---
#
# ## 1. 파이썬의 핵심 철학 (PEP 20 – The Zen of Python)
#
# 파이썬은 **가독성**과 **단순함**을 최우선으로 설계되었습니다. `import this` 명령어를 실행하면 아래와 같은 19개의 격언을 볼 수 있습니다.
#
# 1. **Beautiful is better than ugly.** (아름다운 것이 추한 것보다 낫다)
# 2. **Explicit is better than implicit.** (명시적인 것이 암시적인 것보다 낫다)
# 3. **Simple is better than complex.** (단순한 것이 복잡한 것보다 낫다)
# 4. **Complex is better than complicated.** (복잡한 것이 난해한 것보다 낫다)
# 5. **Readability counts.** (가독성은 중요하다)
# 6. **...** (이하 생략)
#
# 이 철학은 파이썬 코드가 **읽기 쉽고** 유지보수가 용이하도록 하는 데 큰 영향을 미칩니다.
#
# ---
#
# ## 2. 주요 특징
#
# | 특징 | 설명 |
# |------|------|
# | **인터프리터 언어** | 코드를 컴파일하지 않고 바로 실행한다. (`python script.py`) |
# | **동적 타이핑** | 변수 선언 시 타입을 명시하지 않는다. 런타임에 타입이 결정된다. |
# | **높은 가독성** | 들여쓰기로 블록을 구분한다(중괄호 대신). |
# | **풍부한 표준 라이브러리** | `datetime`, `json`, `os`, `re` 등 수백 개의 모듈이 기본 제공된다. |
# | **멀티 패러다임** | 절차적, 객체지향, 함수형 프로그래밍을 모두 지원한다. |
# | **플랫폼 독립성** | Windows, macOS, Linux, 심지어 모바일(예: Kivy)에서도 실행 가능. |
# | **확장성** | C/C++ 로 구현된 모듈을 쉽게 연결해 성능을 보강할 수 있다. |
# | **대규모 생태계** | PyPI(Python Package Index)에는 300,000개가 넘는 서드파티 패키지가 있다. |
# | **커뮤니티와 문서** | 공식 문서, 튜토리얼, Stack Overflow, GitHub 등 지원이 풍부하다. |
#
# ---
#
# ## 3. 파이썬 버전
#
# | 버전 | 출시 연도 | 특징 | 현재 지원 상태 |
# |------|----------|------|----------------|
# | **Python 2.7** | 2010 | 오래된 프로젝트와 호환성 유지용 | 2020년 1월 1일에 공식 지원 종료 |
# | **Python 3.x** | 2008~현재 | 모든 새로운 기능·표준 라이브러리·버그 수정 포함 | 최신 LTS(Latest Long‑Term Support) 버전은 3.12 (2024년 10월 기준) |
#
# > **권장**: 새 프로젝트는 반드시 Python 3.x를 사용하세요. Python 2와는 문법·표현식이 다소 차이가 있습니다.
#
# ---
#
# ## 4. 기본 문법 예시
#
# ```python
# # Hello, World!
# print("Hello, World!")
#
# # 변수와 동적 타이핑
# x = 10          # 정수
# y = 3.14        # 실수
# name = "Alice" # 문자열
#
# # 리스트와 딕셔너리
# numbers = [1, 2, 3, 4, 5]
# person = {"name": "Bob", "age": 30}
#
# # 조건문
# if x > 5:
#     print("x는 5보다 큽니다.")
# elif x == 5:
#     print("x는 5와 같습니다.")
# else:
#     print("x는 5보다 작습니다.")
#
# # 반복문 (for)
# for n in numbers:
#     print(n * 2)
#
# # 함수 정의
# def greet(name: str) -> str:
#     """인사말을 반환합니다."""
#     return f"Hello, {name}!"
#
# print(greet("Charlie"))
#
# # 클래스 (객체지향)
# class Animal:
#     def __init__(self, species: str):
#         self.species = species
#
#     def speak(self):
#         raise NotImplementedError
#
# class Dog(Animal):
#     def speak(self):
#         return "멍멍!"
#
# dog = Dog("개")
# print(dog.speak())   # 멍멍!
# ```
#
# ### 주요 문법 포인트
# - **들여쓰기**: 블록을 구분하는 데 반드시 4칸(스페이스) 혹은 탭을 사용합니다. 혼용하면 `IndentationError`가 발생합니다.
# - **주석**: `#` 으로 한 줄 주석, `'''` 혹은 `"""` 로 여러 줄 주석(문서 문자열) 작성.
# - **타입 힌트**(Python 3.5+): `def func(a: int) -> str:` 와 같이 변수·함수에 타입을 명시해 IDE와 정적 분석 도구가 도움을 주게 할 수 있습니다.
#
# ---
#
# ## 5. 파이썬이 주로 쓰이는 분야
#
# | 분야 | 활용 예시 | 주요 라이브러리 |
# |------|----------|-----------------|
# | **웹 개발** | 백엔드 API, 웹 사이트 | Django, Flask, FastAPI |
# | **데이터 과학** | 데이터 분석, 시각화, 모델링 | NumPy, pandas, Matplotlib, seaborn |
# | **인공지능·머신러닝** | 딥러닝, 자연어 처리, 강화학습 | TensorFlow, PyTorch, scikit-learn, Hugging Face Transformers |
# | **자동화·스크립트** | 파일 처리, 시스템 관리, 테스트 자동화 | `os`, `shutil`, `subprocess`, Selenium |
# | **과학·공학** | 시뮬레이션, 수치 해석 | SciPy, SymPy, Jupyter Notebook |
# | **게임 개발** | 2D/3D 게임, 프로토타이핑 | Pygame, Panda3D |
# | **데스크톱 앱** | GUI 어플리케이션 | Tkinter, PyQt, Kivy |
# | **임베디드·IoT** | 라즈베리 파이, 마이크로컨트롤러 | MicroPython, CircuitPython |
#
# ---
#
# ## 6. 파이썬 개발 환경 설정
#
# ### 6.1. 설치
#
# - **Windows**: 공식 설치 프로그램(`python‑3.x‑amd64.exe`)을 다운로드 후 *Add Python to PATH* 옵션을 체크.
# - **macOS**: Homebrew (`brew install python`) 또는 공식 DMG 파일.
# - **Linux**: 대부분 배포판에 `python3`와 `pip3`가 기본 포함. `apt`, `dnf`, `pacman` 등 패키지 매니저 사용.
#
# > **Tip**: `pyenv`(다중 파이썬 버전 관리)와 `conda`(패키지·환경 관리)를 활용하면 프로젝트마다 독립된 환경을 만들 수 있어 충돌을 방지할 수 있습니다.
#
# ### 6.2. 가상 환경(Virtual Environment)
#
# ```bash
# # venv 모듈 사용 (Python 3.3+)
# python -m venv myenv          # 가상 환경 생성
# source myenv/bin/activate      # macOS/Linux 활성화
# myenv\Scripts\activate.bat     # Windows 활성화
#
# # 패키지 설치
# pip install requests numpy
# ```
#
# ### 6.3. IDE / 편집기
#
# | 도구 | 특징 |
# |------|------|
# | **VS Code** | 풍부한 확장(Python, Pylance), 디버거, Jupyter 통합 |
# | **PyCharm** | 강력한 코드 분석·리팩터링, 프로페셔널 버전(유료) |
# | **Jupyter Notebook / Lab** | 대화형 데이터 분석·시각화에 최적 |
# | **Vim / Emacs** | 경량·키보드 중심, 플러그인으로 파이썬 지원 |
#
# ---
#
# ## 7. 패키지 관리와 배포
#
# ### 7.1. pip (Python Package Installer)
#
# ```bash
# # 최신 pip로 업그레이드
# python -m pip install --upgrade pip
#
# # 패키지 설치
# pip install pandas
#
# # 요구사항 파일 활용
# pip install -r requirements.txt
# ```
#
# ### 7.2. PyPI에 패키지 배포
#
# 1. `setup.py` 또는 최신 `pyproject.toml` 작성
# 2. `twine`을 이용해 배포
#
# ```bash
# python -m build                # wheel 및 sdist 생성
# twine upload dist/*            # PyPI에 업로드
# ```
#
# ### 7.3. 의존성 관리 도구
#
# - **poetry**: `pyproject.toml` 기반, 의존성 해결·패키징을 간편하게.
# - **pipenv**: `Pipfile`과 `Pipfile.lock`을 사용해 가상 환경과 의존성을 동시에 관리.
#
# ---
#
# ## 8. 성능 최적화 방안
#
# | 방법 | 설명 |
# |------|------|
# | **Cython** | 파이썬 코드를 C로 변환해 속도 향상 (특히 루프 중심 연산) |
# | **Numba** | JIT(Just‑In‑Time) 컴파일러, `@jit` 데코레이터로 함수 가속 |
# | **멀티프로세싱** | `multiprocessing` 모듈로 CPU 코어를 활용 (GIL 회피) |
# | **멀티스레딩** | I/O‑바운드 작업에 `threading` 사용 (GIL 제한) |
# | **비동기 I/O** | `asyncio`, `aiohttp` 등으로 비동기 네트워크·파일 처리 |
# | **프로파일링** | `cProfile`, `line_profiler` 로 병목 지점 파악 후 최적화 |
#
# > **주의**: 파이썬은 **GIL(Global Interpreter Lock)** 때문에 CPU‑바운드 작업에서는 멀티스레딩이 큰 효과를 주지 못합니다. 대신 멀티프로세싱이나 C 확장 모듈을 고려하세요.
#
# ---
#
# ## 9. 커뮤니티와 학습 자료
#
# | 자료 | 설명 |
# |------|------|
# | **공식 문서** | https://docs.python.org/3/ (영문, 한국어 번역도 존재) |
# | **PEP(파이썬 개선 제안)** | 새로운 기능·표준 라이브러리 설계 과정을 확인 가능 |
# | **Python.org** | 다운로드, 튜토리얼, 이벤트(예: PyCon) |
# | **Stack Overflow** | 질문·답변 커뮤니티 (태그 `python`) |
# | **Real Python**, **Corey Schafer**(YouTube) | 실전 튜토리얼 |
# | **Kaggle** | 데이터 과학·머신러닝 실습용 노트북 |
# | **GitHub** | 오픈소스 프로젝트 탐색·기여 |
#
# ---
#
# ## 10. 파이썬을 배우는 로드맵 (초급 → 고급)
#
# 1. **기초 문법**
#    - 변수, 자료형, 연산자, 제어문, 함수, 기본 입출력
# 2. **데이터 구조**
#    - 리스트, 튜플, 딕셔너리, 집합, 리스트 컴프리헨션
# 3. **파일·예외 처리**
#    - `open`, `with`, `try/except`
# 4. **객체지향 프로그래밍**
#    - 클래스·상속·다형성·특수 메서드(`__init__`, `__str__` 등)
# 5. **표준 라이브러리 활용**
#    - `datetime`, `json`, `re`, `collections`, `itertools`
# 6. **가상 환경·패키지 관리**
#    - `venv`, `pip`, `poetry` 등
# 7. **실전 프로젝트**
#    - 웹 스크래핑, 간단한 웹 API, 데이터 분석 프로젝트 등
# 8. **고급 주제**
#    - 비동기 프로그래밍(`asyncio`), 멀티프로세싱, C 확장, 타입 힌트, 테스트(`pytest`)
# 9. **특정 분야 심화**
#    - 웹 개발 → Django/Flask/FastAPI
#    - 데이터 과학 → pandas, NumPy, Matplotlib, scikit‑learn
#    - AI/ML → TensorFlow, PyTorch, Hugging Face
#
# ---
#
# ## 11. 마무리
#
# 파이썬은 **읽기 쉬운 문법**, **방대한 라이브러리**, **활발한 커뮤니티** 덕분에 **초보자부터 전문가까지** 폭넓게 활용할 수 있는 언어입니다. 특히 **데이터 과학·AI**, **웹 개발**, **자동화** 분야에서 강력한 입지를 가지고 있으며, **다양한 플랫폼**에서 실행 가능하다는 장점이 있습니다.
#
# > **한 줄 요약**: 파이썬은 “**코드를 쓰는 것이 아니라 생각을 쓰는**” 언어이며, 여러분이 어떤 아이디어를 구현하든 빠르게 프로토타입을 만들고, 필요에 따라 확장·배포할 수 있게 해 줍니다.
#
# 궁금한 점이 있으면 언제든 질문해 주세요! 🚀

# %% [markdown]
# # LCEL

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser
print(type(chain))
print(chain)
# Out:
# <class 'langchain_core.runnables.base.RunnableSequence'>
# first=ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 개발자입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]) middle=[ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x000001D80BFAB4D0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001D80BFBD8E0>, root_client=<openai.OpenAI object at 0x000001D80BA955B0>, root_async_client=<openai.AsyncOpenAI object at 0x000001D80BFAB530>, model_name='meta-llama/llama-4-scout-17b-16e-instruct', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='https://api.groq.com/openai/v1')] last=StrOutputParser()

# %%
response = chain.invoke({"input":"지구의 자전주기는 얼마인가요?"})

# %%
print(type(response))
print(response)
# Out:
# <class 'str'>
# 지구의 자전주기는 24시간입니다. 이를 하루라고 부릅니다.
