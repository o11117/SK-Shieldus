# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests; import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.3
# bs4 버전 = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
# url = f'https://news.naver.com/section/{sid}'
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)
# Out:
# https://news.naver.com/section/105

# %%
req_param = {
    'sid': 105
}

url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36"
}

# requests 의 get() 함수 호출하기 
# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
res = requests.get(url, headers = req_header)
print(res.status_code, res.ok)
print(type(res))
print(res)
if res.ok:
    html = res.text
   

# BeautifulSoup 객체 생성  
    soup = BeautifulSoup(html, "html.parser")
    # print(soup)
    # CSS 선택자
    # print(soup.select("div.sa_text a[href*='mnews/article']"))
    a_tags = soup.select("div.sa_text a[href*='news/article/'].sa_text_title") 

    print(len(a_tags))
    print(type(a_tags))
    for idx,a_tag in enumerate(a_tags,1):        
            title = a_tag.text.strip()
            link = a_tag['href']
            #print(len(title))
            print(f'{idx} {title} {link}')
else:
    # 응답(response)이 Error 이면 status code 출력
    print(f'Error: {res.status_code}')
# <a> 태그 리스트 순회하기    

# 응답(response)이 Error 이면 status code 출력
# Out:
# https://news.naver.com/section/105
# 200 True
# <class 'requests.models.Response'>
# <Response [200]>
# 44
# <class 'bs4.element.ResultSet'>
# 1 카카오그룹, 집중호우 피해 복구 위해 15억원 기부 https://n.news.naver.com/mnews/article/030/0003334393
# 2 KT, 솔트룩스·크라우드웍스와 '원팀'…국가대표 AI 도전장 https://n.news.naver.com/mnews/article/008/0005225603
# 3 베이커 '핵심' 제자 백민경 교수, 또 일냈다…"APEC 최고 연구 성과" https://n.news.naver.com/mnews/article/008/0005225606
# 4 KT, 경찰 바디캠 도입 사업 수주…"5년간 1만 4000명에 보급" https://n.news.naver.com/mnews/article/421/0008386847
# 5 한국형 위성항법시스템 구축 본격화…지상 안테나국 착공 https://n.news.naver.com/mnews/article/030/0003334371
# 6 "비수도권 '외국인 집중거주지역', 7년 새 3배로" https://n.news.naver.com/mnews/article/001/0015523041
# 7 크래프톤, 배틀그라운드 'PNC 2025' 개막…마지막날 에스파 공연 https://n.news.naver.com/mnews/article/018/0006071827
# 8 CJ ENM, 韓 엔터기업 최초 중동법인 설립 https://n.news.naver.com/mnews/article/138/0002201192
# 9 삼천당제약 "경구용 GLP-1, 오리지널 약물과 동등성 확인" https://n.news.naver.com/mnews/article/015/0005161626
# ...

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}

def print_news(section):  #print_new(103,'생활/문화') 
    sid = section_dict[section]
    url = f'https://news.naver.com/section/{sid}'
    print(f'{url} {section} 뉴스')

    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
    }
    

    res = requests.get(url, headers = req_header)
    print(res.status_code, res.ok)
    if res.ok:
        html = res.text
        # BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, "html.parser")
        a_tags = soup.select("div.sa_text a[href*='news/article/'].sa_text_title") 

        print(len(a_tags))

        for idx,a_tag in enumerate(a_tags,1):        
            title = a_tag.text.strip()
            link = a_tag['href']
            #print(len(title))
            print(f'{idx} {title} {link}')
    else:
        print(f'Error: {res.status_code}')

# %%
print_news('세계')  # print_news(105,'IT/과학')
# Out:
# https://news.naver.com/section/104 세계 뉴스
# 200 True
# 45
# 1 트럼프 "日과 협상…관세율 15%, 車·쌀 시장 개방"(종합) https://n.news.naver.com/mnews/article/277/0005626757
# 2 美, 日 車관세도 15%로 전격 인하…이시바 "트럼프 회담도 고려" https://n.news.naver.com/mnews/article/079/0004048060
# 3 "오바마, 쿠데타 주도"…'엡스타인 스캔들' 트럼프, 폭주 https://n.news.naver.com/mnews/article/008/0005225493
# 4 “韓, 관세보다 좋은것 내놔야 트럼프 설득 가능” https://n.news.naver.com/mnews/article/021/0002724705
# 5 트럼프정부, 골든돔에 스페이스X 대신 아마존 등과 협의 https://n.news.naver.com/mnews/article/015/0005161427
# 6 日자민당 들쑤시는 ‘이시바 끌어내리기’… ‘앙숙’ 아소 움직이나 https://n.news.naver.com/mnews/article/081/0003560002
# 7 美, 필리핀과 무역협상 타결…“필리핀산 상호관세 19%·미국산 0%”[트럼프 스트레스] https://n.news.naver.com/mnews/article/119/0002982405
# 8 미국 자동차 빅3 "일본 차 관세 완화는 나쁜 합의" https://n.news.naver.com/mnews/article/052/0002223303
# 9 타이완 GD 콘서트 9억 챙긴 암표상 적발...10배 넘는 웃돈 받아 https://n.news.naver.com/mnews/article/052/0002223302
# 10 쌀 내주고 차 지킨 日 관세 완화에…미국차업계 ‘반발’ https://n.news.naver.com/mnews/article/021/0002724722
# ...

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=838002&no=16&week=wed',
    'user-agent':'user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/838002/16/20250603223756_38a667850421aa1e992a864f980dfb7a_IMAG01_8.jpg',
    'https://image-comic.pstatic.net/webtoon/838002/16/20250603223756_38a667850421aa1e992a864f980dfb7a_IMAG01_9.jpg',
    'https://image-comic.pstatic.net/webtoon/838002/16/20250603223756_38a667850421aa1e992a864f980dfb7a_IMAG01_10.jpg'
]

for img_url in img_urls:
    
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers=req_header)
    print(res.ok, res.status_code)
    if res.ok:
        # binary 응답 데이터 가져오기
        img_data = res.content
        # url에서 파일명만 추출하기
        file_name = os.path.basename(img_url)
        print(file_name)
        # binday data를 file에 write하기
        with open(file_name, 'wb') as file:
            print(f'Writing to{file_name}({len(img_data):,} bytes)')
            file.write(img_data)
# Out:
# True 200
# 20250603223756_38a667850421aa1e992a864f980dfb7a_IMAG01_8.jpg
# Writing to20250603223756_38a667850421aa1e992a864f980dfb7a_IMAG01_8.jpg(140,842 bytes)
# True 200
# 20250603223756_38a667850421aa1e992a864f980dfb7a_IMAG01_9.jpg
# Writing to20250603223756_38a667850421aa1e992a864f980dfb7a_IMAG01_9.jpg(115,541 bytes)
# True 200
# 20250603223756_38a667850421aa1e992a864f980dfb7a_IMAG01_10.jpg
# Writing to20250603223756_38a667850421aa1e992a864f980dfb7a_IMAG01_10.jpg(85,205 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests; import os
from bs4 import BeautifulSoup

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=840329&no=5&week=mon'
req_header = {
    'referer' : webtoon_url,
    'user-agent' : 'user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
}
res = requests.get(webtoon_url)
print(res.status_code, res.ok)

if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("img[src^='https://image-comic.pstatic.net/webtoon/840329/5/20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01']")))
    
    #img src file명을 저장할 list 선언
    img_url_list = []
    img_tags = soup.select("img[src*='IMAG01']") #img_tags의 타입은 Resultset [Tag, Tag,...]
    for img_tag in img_tags: # img_tag의 타입은 Tag <img>
        img_url = img_tag['src']
        img_url_list.append(img_url)
    # print(len(img_url_list), img_url_list[0:2])

    #img 디렉토리가 없으면 생성하기
    imgdir_name = 'img'
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)

    for jpg_url in img_url_list:
        res = requests.get(jpg_url, headers=req_header)
        if res.ok:
            img_data = res.content
            # img/xxx.jpg 디렉토리명과 jpg파일명을 join
            dir_name = os.path.join(imgdir_name,os.path.basename(jpg_url))
            with open(dir_name,'wb') as file:
                print(f'Writing to {os.path.basename(jpg_url)}({len(img_data):,} bytes)')
                file.write(img_data)
        else:
            print(f'Error Code = {res.status_code}')
# Out:
# 200 True
# 146
# Writing to 20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01_1.jpg(133,195 bytes)
# Writing to 20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01_2.jpg(250,197 bytes)
# Writing to 20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01_3.jpg(137,068 bytes)
# Writing to 20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01_4.jpg(232,360 bytes)
# Writing to 20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01_5.jpg(202,055 bytes)
# Writing to 20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01_6.jpg(197,400 bytes)
# Writing to 20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01_7.jpg(192,466 bytes)
# Writing to 20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01_8.jpg(117,276 bytes)
# Writing to 20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01_9.jpg(192,582 bytes)
# Writing to 20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01_10.jpg(176,863 bytes)
# Writing to 20250722095336_6d04897e64dd92075433fc073fecc424_IMAG01_11.jpg(166,724 bytes)
# ...

# %% [markdown]
# ### 리팩토링 코드

# %%
import requests
from bs4 import BeautifulSoup
import os

# 기본 설정
url = 'https://comic.naver.com/webtoon/detail?titleId=833255&no=4&week=finish'
req_header = {'referer': url}
imgdir_name = 'img'

# 이미지 저장 폴더가 없으면 생성
os.makedirs(imgdir_name, exist_ok=True)

# 웹 페이지 요청 및 확인
res = requests.get(url)
if not res.ok:
    print(f'Error Code = {res.status_code}')
    exit()

# 이미지 URL 추출
soup = BeautifulSoup(res.text, 'html.parser')
img_url_list = [img_tag['src'] for img_tag in soup.select("img[src*='IMAG01']")]

# 이미지 다운로드
for img_url in img_url_list:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))
        with open(file_path, 'wb') as file:
            print(f'Writing to {file_path} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error Code = {res.status_code} for {img_url}')
# Out:
# Writing to img\20241015123448_7fa3c9b404a984b3150f245ca5a35c5e_IMAG01_1.jpg (173,502 bytes)
# Writing to img\20241015123448_7fa3c9b404a984b3150f245ca5a35c5e_IMAG01_2.jpg (152,674 bytes)
# Writing to img\20241015123448_7fa3c9b404a984b3150f245ca5a35c5e_IMAG01_3.jpg (188,059 bytes)
# Writing to img\20241015123448_7fa3c9b404a984b3150f245ca5a35c5e_IMAG01_4.jpg (119,420 bytes)
# Writing to img\20241015123448_7fa3c9b404a984b3150f245ca5a35c5e_IMAG01_5.jpg (155,205 bytes)
# Writing to img\20241015123448_7fa3c9b404a984b3150f245ca5a35c5e_IMAG01_6.jpg (190,198 bytes)
# Writing to img\20241015123448_7fa3c9b404a984b3150f245ca5a35c5e_IMAG01_7.jpg (220,529 bytes)
# Writing to img\20241015123448_7fa3c9b404a984b3150f245ca5a35c5e_IMAG01_8.jpg (208,657 bytes)
# Writing to img\20241015123448_7fa3c9b404a984b3150f245ca5a35c5e_IMAG01_9.jpg (184,520 bytes)
# Writing to img\20241015123448_7fa3c9b404a984b3150f245ca5a35c5e_IMAG01_10.jpg (73,353 bytes)
# ...

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    'img1': open('f1.jpg','rb'),
    'img2': open('f2.jpg','rb')
}
print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
res = requests.post(url,files=upload_files,)
print(res.status_code)
print(type(res.json()))
# print(res.json())
print(res.json()['files']['img1'])
# Out:
# {'img1': <_io.BufferedReader name='f1.jpg'>, 'img2': <_io.BufferedReader name='f2.jpg'>}
# 200
# <class 'dict'>
# data:application/octet-stream;base64,...

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청
import urllib.request

client_id = "1Oza_OIQDo6xBex4sgNU" # 개발자센터에서 발급받은 Client ID 값
client_secret = "eWJgIg5SYy" # 개발자센터에서 발급받은 Client Secret 값

code = "0"
url = "https://openapi.naver.com/v1/captcha/nkey?code=" + code
#Request 객체생성
request = urllib.request.Request(url)
#요청헤더 설정
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
#서버에 request 전달
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"key":"AVodfyfj2xk7LlKL"}

# %%
# 캡차 이미지 요청
import urllib.request

client_id = "1Oza_OIQDo6xBex4sgNU" # 개발자센터에서 발급받은 Client ID 값
client_secret = "eWJgIg5SYy" # 개발자센터에서 발급받은 Client Secret 값
key = "Fito7F09UzXcJoPq" # 캡차 Key 값
url = "https://openapi.naver.com/v1/captcha/ncaptcha.bin?key=" + key

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    print("캡차 이미지 저장")
    response_body = response.read()
    with open('captcha.jpg', 'wb') as f:
        f.write(response_body)
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[20], line 12
#      10 request.add_header("X-Naver-Client-Id",client_id)
#      11 request.add_header("X-Naver-Client-Secret",client_secret)
# ---> 12 response = urllib.request.urlopen(request)
#      13 rescode = response.getcode()
#      14 if(rescode==200):
#
# File c:\Users\user\anaconda3\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File c:\Users\user\anaconda3\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# ...

# %%
#  사용자 입력값 검증 요청
import urllib.request
client_id = "1Oza_OIQDo6xBex4sgNU" # 개발자센터에서 발급받은 Client ID 값
client_secret = "eWJgIg5SYy" # 개발자센터에서 발급받은 Client Secret 값
code = "1"
key = "IWjCiUVCQUn99nAV"
value = "YUBRTA9"
url = "https://openapi.naver.com/v1/captcha/nkey?code=" + code + "&key=" + key + "&value=" + value
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"result":true,"responseTime":34.6}

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
import os
from dotenv import load_dotenv
import requests

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
client_id = os.getenv("1Oza_OIQDo6xBex4sgNU")  # .env 파일의 NAVER_CLIENT_ID
client_secret = os.getenv("eWJgIg5SYy")  # .env 파일의 NAVER_CLIENT_SECRET
key = "Fito7F09UzXcJoPq"
# os.getenv("QN13rdRyxoMbtEYF")  # .env 파일의 NAVER_CAPTCHA_KEY

# 사용자 입력값
code = "1"
value = "5EBUL2F"  # 실제 사용시 사용자 입력값으로 대체 필요

# URL 구성
# query string key1=value1&key2=value2
url = f"https://openapi.naver.com/v1/captcha/nkey?code={code}&key={key}&value={value}"

# 요청 헤더
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}

# 요청 보내기
try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # 4xx, 5xx 오류 발생시 예외 발생
    
    # 응답 처리
    print(response.text)
    
except requests.exceptions.RequestException as e:
    print(f"Error occurred: {e}")
    print(f"Status Code: {response.status_code if 'response' in locals() else 'N/A'}")
# Out:
# Error occurred: 401 Client Error: Unauthorized for url: https://openapi.naver.com/v1/captcha/nkey?code=1&key=Fito7F09UzXcJoPq&value=5EBUL2F
# Status Code: 401

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
from pprint import pprint
import os
from dotenv import load_dotenv

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
# client_id = os.getenv("1Oza_OIQDo6xBex4sgNU")  # .env 파일의 NAVER_CLIENT_ID
# client_secret = os.getenv("eWJgIg5SYy")  # .env 파일의 NAVER_CLIENT_SECRET

headers = {
    'X-Naver-Client-Id': '1Oza_OIQDo6xBex4sgNU',
    'X-Naver-Client-Secret': 'eWJgIg5SYy',
}

# query string 문자열을 dict 선언
payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'date'
}

url = 'https://openapi.naver.com/v1/search/blog.json' #?query=파이썬&display=100&sort=sim

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기
items_data = res.json()['items']
# pprint(res.json())
print(type(res.json()))
print(len(items_data), type(items_data), type(items_data[0]))
pprint(items_data[0])
#[{},{},{}] 
# [] - 100 개의 데이터, {title:'',link:''} - 1개의 블로그 글 데이터
# Out:
# <class 'dict'>
# 10 <class 'list'> <class 'dict'>
# {'bloggerlink': 'blog.naver.com/kevinpanda0801',
#  'bloggername': 'kevinpanda0801님의 블로그',
#  'description': '',
#  'link': 'https://blog.naver.com/kevinpanda0801/223944120302',
#  'postdate': '20250723',
#  'title': '2025.7.16 <b>파이썬</b>'}

# %%
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
items_list = list()
item_list = []
for item in items_data:
#     print(item)
    item_list.append(item['title'])
    item_list.append(item['bloggername'])
    item_list.append(item['description'])
    item_list.append(item['bloggerlink'])
    item_list.append(item['link'])
    item_list.append(item['postdate'])

    items_list.append(item_list)
    item_list = []

print(items_list) #[[],[],[]]

# 'data/nhnblog.txt' 파일 생성하기
with open('data/nhnblog.txt','w',encoding="utf-8")as file:
    for items in items_list:
        for item in items:
            item = item + '\n'
            file.write(item)
        file.write('-'*150+'\n')
# Out:
# [['2025.7.16 <b>파이썬</b>', 'kevinpanda0801님의 블로그', '', 'blog.naver.com/kevinpanda0801', 'https://blog.naver.com/kevinpanda0801/223944120302', '20250723'], ['하루 목표 달성률 높이는 체크리스트 작성법', '도형레코드 DH record', "대신 '일주일 안에 <b>파이썬</b> 기본 문법 강의 3개 수강하고 예제 코드 따라 하기'와 같이 현실적인 목표를 설정하는 것이 바람직합니다. 목표 설정 시 현재 자신의 역량 수준을 객관적으로 평가하는 과정이... ", 'blog.naver.com/jigengs', 'https://blog.naver.com/jigengs/223911881591', '20250723'], ['spyder IDE로 python 사용하기', '세상을 가치있게', 'Spyder의 사용은 anacoda 를 설치하여 사용하는 것을 권장: Anaconda 프로그램을 설치하면, Python과 함께 Jupyter Notebook, NumPy, pandas, matplotlib 등 <b>파이썬</b>으로 데이터 사이언스를... ', 'blog.naver.com/gwihyeonseo', 'https://blog.naver.com/gwihyeonseo/223944119740', '20250723'], ['[python] pickle, copy, mask', '세상을 가치있게', 'pickle 모듈은 <b>파이썬</b> 객체를 파일에 저장하거나 네트워크를 통해 전송할 수도 있다. pickle.dump(): <b>파이썬</b> 객체를 파일에 저장하는 데 사용되며, 첫 번째 인자는 저장할 객체, 두 번째 인자는 파일... ', 'blog.naver.com/gwihyeonseo', 'https://blog.naver.com/gwihyeonseo/223944116543', '20250723'], ['<b>파이썬</b> Python 기본 개념 정리
# ...
