# %%
import requests
import os
from bs4 import BeautifulSoup
def getHtml(url):
    try:
        #요청 헤더 설정 : 브라우저 정보
        req_header = {
            "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
        }

        # requests 의 get() 함수 호출하기 
        res=requests.get(url,headers=req_header)
        res.encoding = 'utf-8'
        res.raise_for_status()

        # 응답(response)이 OK 이면 text 추출
        html = res.text
        return html
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        return "Error"
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return "Error"   
url = getHtml("http://42.55.106.157:48623/bin.sh")
print(url)
# Out:
# Error fetching URL http://42.55.106.157:48623/bin.sh: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Error

# %%
import pandas as pd
import requests

def get_html(url):
    try:
        req_header = {
            "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36"
        }
        res = requests.get(url, headers=req_header, timeout=10)
        res.encoding = 'utf-8'
        res.raise_for_status()
        return res.text
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return ""

# top-1m.csv 파일 읽기
df = pd.read_csv('./data/top-1m.csv', header=None, names=['rank', 'url'])

results = []
for i, row in df.head(1000).iterrows():  # head(10) 대신 전체 처리하려면 .iterrows()만 사용
    url = "http://" + row['url']
    html_code = get_html(url)
    results.append({'html_code': html_code, 'repu': 'benign'})

# 결과를 CSV로 저장
result_df = pd.DataFrame(results)
result_df.to_csv('benign_html.csv', index=False, quoting=1)  # quoting=1: csv.QUOTE_ALL
# Out:
# Error fetching http://facebook.com: 400 Client Error: Bad Request for url: https://www.facebook.com/
# Error fetching http://onclkds.com: HTTPConnectionPool(host='onclkds.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C7F9EE450>: Failed to resolve 'onclkds.com' ([Errno 11002] getaddrinfo failed)"))
# Error fetching http://ok.ru: 503 Server Error:  for url: https://ok.ru/
# Error fetching http://microsoftonline.com: HTTPConnectionPool(host='microsoftonline.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0C834CB0>: Failed to resolve 'microsoftonline.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://whatsapp.com: 400 Client Error: Bad Request for url: https://www.whatsapp.com/
# Error fetching http://adobe.com: HTTPSConnectionPool(host='www.adobe.com', port=443): Read timed out. (read timeout=10)
# Error fetching http://googleusercontent.com: 404 Client Error: Not Found for url: http://googleusercontent.com/
# Error fetching http://tianya.cn: HTTPConnectionPool(host='tianya.cn', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C04428470>: Failed to resolve 'tianya.cn' ([Errno 11002] getaddrinfo failed)"))
# Error fetching http://china.com: HTTPConnectionPool(host='china.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0442A150>: Failed to resolve 'china.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://rakuten.co.jp: HTTPSConnectionPool(host='www.rakuten.co.jp', port=443): Read timed out. (read timeout=10)
# Error fetching http://adf.ly: 403 Client Error: Forbidden for url: https://publisher.linkvertise.com/adfly
# Error fetching http://fbcdn.net: 400 Client Error: Bad Request for url: https://www.facebook.com/
# Error fetching http://indeed.com: 403 Client Error: Forbidden for url: https://indeed.com/
# Error fetching http://xinhuanet.com: 503 Server Error: Backend fetch failed for url: http://xinhuanet.com/
# Error fetching http://google.com.co: HTTPConnectionPool(host='google.com.co', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0
com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0587AD20>: Failed to resolve 'newstarads.com' ([Errno 11002] getaddrinfo failed)"))
# Error fetching http://canva.com: 403 Client Error: Forbidden for url: https://www.canva.com/
# Error fetching http://wittyfeed.com: HTTPConnectionPool(host='wittyfeed.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C7DC73DA0>, 'Connection to wittyfeed.com timed out. (connect timeout=10)'))
# Error fetching http://taleo.net: HTTPConnectionPool(host='taleo.net', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C0C834290>, 'Connection to taleo.net timed out. (connect timeout=10)'))
# Error fetching http://udemy.com: 403 Client Error: Forbidden for url: https://www.udemy.com/
# Error fetching http://livedoor.jp: 403 Client Error: Forbidden for url: http://livedoor.jp/
# Error fetching http://sciencedirect.com: 403 Client Error: Forbidden for url: https://www.sciencedirect.com/
# Error fetching http://reverso.net: 403 Client Error: Forbidden for url: http://reverso.net/
# Error fetching http://doublepimpssl.com: HTTPSConnectionPool(host='doublepimpssl.com', port=443): Read timed out. (read timeout=10)
# Error fetching http://cloudfront.net: HTTPConnectionPool(host='cloudfront.net', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0C8372F0>: Failed to resolve 'cloudfront.net' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://jrj.com.cn: 514 Server Error: Frequency Capped for url: http://jrj.com.cn/
# Error fetching http://upwork.com: 403 Client Error: Forbidden for url: https://www.upwork.com
# Error fetching http://incometaxindiaefiling.gov.in: HTTPConnectionPool(host='incometaxindiaefiling.gov.in', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0442B560>: Failed to resolve 'incometaxindiaefiling.gov.in' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://intuit.com: 429 Client Error: Too Many Requests for url: https://www.intuit.com/
# Error fetching http://piz7ohhujogi.com: HTTPConnectionPool(host='piz7ohhujogi.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C7D88EAB0>: Failed to resolve 'piz7ohhujogi.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://cerpen.co.id: HTTPConnectionPool(host='cerpen.co.id', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0C837950>: Failed to resolve 'cerpen.co.id' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://behance.net: 403 Client Error: Forbidden for url: https://www.behance.net/
# Error fetching http://doublepimp.com: HTTPConnectionPool(host='doublepimp.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C0587AD50>, 'Connection to doublepimp.com timed out. (connect timeout=10)'))
# Error fetching http://glassdoor.com: 403 Client Error: Forbidden for url: http://glassdoor.com/
# Error fetching http://uidai.gov.in: HTTPConnectionPool(host='uidai.gov.in', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C7DC73D70>, 'Connection to uidai.gov.in timed out. (connect timeout=10)'))
# Error fetching http://ytimg.com: HTTPConnectionPool(host='ytimg.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0C835760>: Failed to resolve 'ytimg.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://ultimate-guitar.com: 403 Client Error: Forbidden for url: https://ultimate-guitar.com/
# Error fetching http://perfecttoolmedia.com: HTTPConnectionPool(host='perfecttoolmedia.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C7DCFE510>: Failed to resolve 'perfecttoolmedia.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://kickstarter.com: 403 Client Error: Forbidden for url: https://www.kickstarter.com/
# Error fetching http://lifebuzz.com: 404 Client Error: Not Found for url: http://lifebuzz.com/
# Error fetching http://sahibinden.com: 403 Client Error: Forbidden for url: https://www.sahibinden.com/
# Error fetching http://pixabay.com: 403 Client Error: Forbidden for url: https://pixabay.com/
# Error fetching http://yandex.ua: HTTPConnectionPool(host='yandex.ua', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0C837B30>: Failed to resolve 'yandex.ua' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://umblr.com: 404 Client Error: Not Found for url: https://umblr.com/
# Error fetching http://billdesk.com: HTTPSConnectionPool(host='billdesk.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'billdesk.com'. (_ssl.c:1000)")))
# Error fetching http://reuters.com: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/
# Error fetching http://list-manage.com: HTTPConnectionPool(host='list-manage.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C7D88E630>, 'Connection to list-manage.com timed out. (connect timeout=10)'))
# Error fetching http://bleacherreport.com: 403 Client Error: Moved Permanently for url: http://bleacherreport.com/
# Error fetching http://shaparak.ir: HTTPConnectionPool(host='shaparak.ir', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C7DBEF830>, 'Connection to shaparak.ir timed out. (connect timeout=10)'))
# Error fetching http://expedia.com: 429 Client Error: Too Many Requests for url: https://www.expedia.com/
# Error fetching http://hilltopads.net: HTTPConnectionPool(host='hilltopads.net', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C7F9011C0>: Failed to resolve 'hilltopads.net' ([Errno 11002] getaddrinfo failed)"))
# Error fetching http://uploaded.net: HTTPConnectionPool(host='uploaded.net', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C0587B800>, 'Connection to uploaded.net timed out. (connect timeout=10)'))
# Error fetching http://wsj.com: 401 Client Error: HTTP Forbidden for url: https://www.wsj.com/
# Error fetching http://newegg.com: 403 Client Error: Forbidden for url: https://www.newegg.com/
# Error fetching http://coinbase.com: 403 Client Error: Forbidden for url: https://www.coinbase.com/
# Error fetching http://wixsite.com: HTTPConnectionPool(host='wixsite.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C7F6B0800>: Failed to resolve 'wixsite.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://hm.com: 403 Client Error: Forbidden for url: https://www.hm.com/
# Error fetching http://jabong.com: HTTPSConnectionPool(host='www.myntra.com', port=443): Read timed out. (read timeout=10)
# Error fetching http://17ok.com: HTTPConnectionPool(host='17ok.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C05879970>, 'Connection to 17ok.com timed out. (connect timeout=10)'))
# Error fetching http://hotels.com: 429 Client Error: Too Many Requests for url: https://www.hotels.com/
# Error fetching http://gogoanime.io: HTTPConnectionPool(host='gogoanime.io', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C05878EC0>, 'Connection to gogoanime.io timed out. (connect timeout=10)'))
# Error fetching http://apple-panda.com: HTTPConnectionPool(host='apple-panda.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C05878BC0>: Failed to resolve 'apple-panda.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://comcast.net: 403 Client Error: Forbidden for url: https://www.xfinity.com/
# Error fetching http://cambridge.org: 403 Client Error: Forbidden for url: https://www.cambridge.org:443/
# Error fetching http://discogs.com: 403 Client Error: Forbidden for url: https://www.discogs.com:443/
# Error fetching http://adp.com: 403 Client Error: Forbidden for url: https://www.adp.com/
# Error fetching http://bandcamp.com: 403 Client Error: Forbidden for url: https://bandcamp.com/
# Error fetching http://weblio.jp: 404 Client Error: 404 for url: https://weblio.jp:443/
# Error fetching http://lolsided.com: HTTPConnectionPool(host='lolsided.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0442ABA0>: Failed to resolve 'lolsided.com' ([Errno 11002] getaddrinfo failed)"))
# Error fetching http://likrete.com: HTTPConnectionPool(host='likrete.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0
port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020C04428F80>: Failed to resolve 'www.fanfiction.net%5c' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://secureserver.net: 404 Client Error: Not Found for url: https://www.secureserver.net/
# Error fetching http://banvenez.com: HTTPConnectionPool(host='banvenez.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0C8372C0>: Failed to resolve 'banvenez.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://fwbntw.com: HTTPConnectionPool(host='fwbntw.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C0587B1A0>, 'Connection to fwbntw.com timed out. (connect timeout=10)'))
# Error fetching http://trulia.com: 403 Client Error: Forbidden for url: https://www.trulia.com/
# Error fetching http://fatosdesconhecidos.com.br: 403 Client Error: Forbidden for url: https://fatosdesconhecidos.com.br/
# Error fetching http://fbsbx.com: 404 Client Error: Not Found for url: https://fbsbx.com/
# Error fetching http://addthis.com: 403 Client Error: Forbidden for url: https://www.oracle.com/
# Error fetching http://caliente.mx: HTTPSConnectionPool(host='www.caliente.mx', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Error fetching http://snapdeal.com: 403 Client Error: Forbidden for url: https://www.snapdeal.com/
# Error fetching http://ecosia.org: 403 Client Error: Forbidden for url: https://www.ecosia.org/
# Error fetching http://thebalance.com: 403 Client Error: Forbidden for url: https://www.thebalancemoney.com:443/
# Error fetching http://fidelity.com: 403 Client Error: Forbidden for url: https://www.fidelity.com/
# Error fetching http://4pda.ru: HTTPConnectionPool(host='4pda.ru', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C04429C10>: Failed to resolve '4pda.ru' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://indianexpress.com: 403 Client Error: Forbidden for url: https://indianexpress.com/
# Error fetching http://cpmofferconvert.com: HTTPConnectionPool(host='cpmofferconvert.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C7DE896D0>: Failed to resolve 'cpmofferconvert.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://how01.com: HTTPConnectionPool(host='how01.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0587A9C0>: Failed to resolve 'how01.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://intel.com: 403 Client Error: Forbidden for url: https://www.intel.com/
# Error fetching http://bhphotovideo.com: 403 Client Error: Forbidden for url: https://bhphotovideo.com/
# Error fetching http://uber.com: 406 Client Error: Not Acceptable for url: https://www.uber.com/
# Error fetching http://kizlarsoruyor.com: 403 Client Error: Forbidden for url: http://kizlarsoruyor.com/
# Error fetching http://kissasian.com: HTTPConnectionPool(host='kissasian.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C7DCDD5B0>, 'Connection to kissasian.com timed out. (connect timeout=10)'))
# Error fetching http://mobile01.com: 403 Client Error: Forbidden for url: https://www.mobile01.com/
# Error fetching http://zing.vn: HTTPSConnectionPool(host='zing.vn', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1000)')))
# Error fetching http://lifewire.com: 403 Client Error: Forbidden for url: https://lifewire.com/
# Error fetching http://disq.us: HTTPConnectionPool(host='disq.us', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000020C7DE88A70>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다'))
# Error fetching http://my-hit.org: HTTPConnectionPool(host='my-hit.org', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020C0442B770>, 'Connection to my-hit.org timed out. (connect timeout=10)'))
# Error fetching http://directrev.com: HTTPConnectionPool(host='directrev.com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0
com', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C04428920>: Failed to resolve 'x48fly.com' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://java.com: 403 Client Error: Forbidden for url: https://java.com/en/
# Error fetching http://awesomeforyou.club: HTTPConnectionPool(host='awesomeforyou.club', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C7DBEF5C0>: Failed to resolve 'awesomeforyou.club' ([Errno 11001] getaddrinfo failed)"))
# Error fetching http://bookmyshow.com: 403 Client Error: Forbidden for url: https://in.bookmyshow.com/
# Error fetching http://artstation.com: 403 Client Error: Forbidden for url: https://www.artstation.com/
# Error fetching http://piriform.com: 404 Client Error: Not Found for url: http://piriform.com/
# Error fetching http://nulltheme.net: HTTPConnectionPool(host='nulltheme.net', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x0000020C0587BFE0>: Failed to resolve 'nulltheme.net' ([Errno 11001] getaddrinfo failed)"))

# %%
# %pip install webdriver-manager
# %pip install selenium
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, WebDriverException
import time
from selenium.webdriver.support.ui import WebDriverWait

# %%
def get_rendered_html_with_selenium(url,headless=True, wait_time=10):
    
    
    options = webdriver.ChromeOptions()

    if headless:
        options.add_argument('headless') # UI 없이 백그라운드에서 실행
        options.add_argument('--no-sandbox') # 샌드박스 비활성화 (Docker 등 환경에서 필요)
        options.add_argument('--disable-dev-shm-usage') # /dev/shm 문제 해결 (Docker 등 환경에서 필요)
        options.add_argument('--disable-gpu') # GPU 사용 안 함 (일부 환경에서 필요)

    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36")
    


    driver = None
    try:
        print(f"Opening URL: {url}")
        driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
        driver.get(url)
    
        WebDriverWait(driver, wait_time).until(
            EC.presence_of_element_located((By.TAG_NAME, 'body'))
        )
        print("Page loaded successfully.")

        # JavaScript 실행 후 렌더링된 HTML 소스 코드 가져오기
        rendered_html = driver.page_source
        return rendered_html

    except TimeoutException:
        print(f"Error: Page loading timed out after {wait_time} seconds for URL: {url}")
        return None
    except WebDriverException as e:
        print(f"WebDriver error for URL {url}: {e}")
        print("Please check if ChromeDriver is correctly installed and its path is set.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred for URL {url}: {e}")
        return None
    finally:
        if driver:
            driver.quit() # 브라우저 닫기

# --- 사용 예시 ---
if __name__ == "__main__":
    # 1. 웹 드라이버 경로 지정 (선택 사항 - PATH에 없거나 특정 버전을 사용하고 싶을 때)
    #    예: Windows에서는 r'C:\Users\YourUser\Downloads\chromedriver.exe'
    #    예: macOS/Linux에서는 '/usr/local/bin/chromedriver'
    #    또는 실행 스크립트와 같은 디렉토리에 드라이버를 두었다면 None으로 두어도 됩니다.
    my_driver_path = None # 'chromedriver'가 PATH에 있다면 None으로 두세요.
                           # 직접 경로를 지정하려면 'C:/path/to/chromedriver.exe' 처럼 변경

    # 테스트할 URL
    test_urls = [
        "https://www.google.com",  # 일반적인 웹사이트
        "https://react.dev/",      # SPA 예시 (JS로 동적 로드)
        "https://www.naver.com/",  # JS가 많은 웹사이트
        "http://invalid.url.com",   # 존재하지 않는 URL 테스트
    ]

    for url_to_check in test_urls:
        print(f"\n--- Processing URL: {url_to_check} ---")
        html_content = get_rendered_html_with_selenium(url_to_check,headless=True)

        if html_content:
            # HTML 콘텐츠의 일부만 출력하여 확인 (너무 길 수 있으므로)
            print(f"Successfully retrieved HTML (first 500 chars):")
            print(html_content[:500])
            print("...")
        else:
            print(f"Failed to retrieve HTML for {url_to_check}")

    print("\nScript finished.")
