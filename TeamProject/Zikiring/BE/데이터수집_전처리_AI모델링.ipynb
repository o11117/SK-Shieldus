# %% [markdown]
# ### 데이터수집

# %%
import pandas as pd
import os
import joblib
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import csv
import 데이터전처리함수.ipynb

# 경로 설정
DATA_PATH = './Feature Website.csv'
MODEL_DIR = './model'
os.makedirs(MODEL_DIR, exist_ok=True)

def log(title, message):
    print(f"[{title}] {message}")

# 데이터 로드
df = pd.read_csv(DATA_PATH, quoting=csv.QUOTE_NONNUMERIC)
log("INFO", f"데이터 로드 완료: {df.shape}")

# 전처리
X = df['html_code']
y = df['repu']  # 0: benign 정상, 1: malicious 악성

vectorizer = TfidfVectorizer()
X_vec = vectorizer.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_vec, y, test_size=0.2, random_state=42)

model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

log("REPORT", classification_report(y_test, y_pred))

# 모델 저장
joblib.dump(model, os.path.join(MODEL_DIR, 'rf_model.pkl'))
joblib.dump(vectorizer, os.path.join(MODEL_DIR, 'vectorizer.pkl'))
log("INFO", "모델 저장 완료")
# Out:
# [INFO] 데이터 로드 완료: (40, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[185], line 32
#      29 X_train, X_test, y_train, y_test = train_test_split(X_vec, y, test_size=0.2, random_state=42)
#      31 model = RandomForestClassifier()
# ---> 32 model.fit(X_train, y_train)
#      33 y_pred = model.predict(X_test)
#      35 log("REPORT", classification_report(y_test, y_pred))
#
# File c:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:359, in BaseForest.fit(self, X, y, sample_weight)
#     356 if issparse(y):
#     357     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 359 X, y = validate_data(
#     360     self,
#     361     X,
#     362     y,
#     363     multi_output=True,
#     364     accept_sparse="csc",
#     365     dtype=DTYPE,
#     366     ensure_all_finite=False,
#     367 )
#     368 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     369 # will raise an error if the underlying tree base estimator can't handle missing
#     370 # values. Only the criterion is required to determine if the tree supports
#     371 # missing values.
#     372 estimator = type(self.estimator)(criterion=self.criterion)
#
# File c:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2971, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2969         y = check_array(y, input_name="y", **check_y_params)
#    2970     else:
# -> 2971         X, y = check_X_y(X, y, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1385, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    (...)
#    1382     input_name="X",
#    1383 )
# -> 1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#    1389 return X, y
#
# File c:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1395, in _check_y(y, multi_output, y_numeric, estimator)
#    1393 """Isolated part of check_X_y dedicated to y validation"""
#    1394 if multi_output:
# -> 1395     y = check_array(
#    1396         y,
#    1397         accept_sparse="csr",
#    1398         ensure_all_finite=True,
#    1399         ensure_2d=False,
#    1400         dtype=None,
#    1401         input_name="y",
#    1402         estimator=estimator,
#    1403     )
#    1404 else:
#    1405     estimator_name = _check_estimator_name(estimator)
#
# File c:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:105, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     103 if not is_array_api and X.dtype == np.dtype("object") and not allow_nan:
#     104     if _object_dtype_isnan(X).any():
# --> 105         raise ValueError("Input contains NaN")
#     107 # We need only consider float arrays, hence can early return for all else.
#     108 if not xp.isdtype(X.dtype, ("real floating", "complex floating")):
#
# ValueError: Input contains NaN

# %% [markdown]
# ### <b>Q1. 데이터 불러오기</b>
# ---
# - Feature Website.xlsx 데이터 불러오기
# - 데이터 둘러보기

# %%
import pandas as pd
import csv
#filename ='Feature Website.csv' #피싱사이트정보
#xlrd 지원불가로 openpyxl 사용할 수 있도록 변경
df = pd.read_csv("Feature Website.csv")
df
# Out:
#                                             html_code       repu
# 0   <!DOCTYPE html>\n<!--[if lt IE 7]> <html lang=...  malicious
# 1   \n\t\n\n\n\t\n\n\t\n\n\n\t\n\n\n\t\n\n\t\n\t\t...  malicious
# 2   <!DOCTYPE html>\n<html lang="en">\n    <head>\...  malicious
# 3   <!DOCTYPE html><html lang="en"><head><style da...  malicious
# 4   <!DOCTYPE html>\n\n\n    \n    \n    \n    \n ...  malicious
# 5   _x000D_\n_x000D_\n_x000D_\n<!DOCTYPE html>_x00...  malicious
# 6   <!doctype html>\n\n<html data-ytrk-page="HOME"...  malicious
# 7   \n\t<!DOCTYPE html>\n\t<html class="no-icon-fo...  malicious
# 8   <!DOCTYPE html>\n<html class="no-js">\n<head>\...  malicious
# 9       <!DOCTYPE html>\n<html class="b-header--bl...  malicious
# 10  <!DOCTYPE html>\n<html lang="mul" dir="ltr">\n...  malicious
# 11  _x000D_\n_x000D_\n<!DOCTYPE html><html lang="e...  malicious
# 12  <!DOCTYPE html><html lang="en"><head><link rel...  malicious
# 13  <!Doctype html>_x000D_\n<html> _x000D_\n<head>...  malicious
# 14  <html lang="en">\n\n<head>\n    <title>Verify ...  malicious
# 15  <!doctype html><html dir="ltr" lang="ko-KR"><h...  malicious
# 16  <HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</...  malicious
# 17  <!doctype html>_x000D_\n<html xmlns="http://ww...  malicious
# 18  _x000D_\n<!DOCTYPE html>_x000D_\n_x000D_\n<htm...  malicious
# 19  <!DOCTYPE html><html lang=en><head><meta http-...  malicious
# 20  <!DOCTYPE html><html lang="en"><head><style da...     benign
# 21  <!doctype html><html lang="en"><head><title da...     benign
# 22  <!DOCTYPE html>\n<!--[if lt IE 8]>      <html ...     benign
# 23  \n<!DOCTYPE html>\n<html id="js-context" class...     benign
# 24  <!DOCTYPE html><html class="no-js"><head><meta...     benign
# 25  _x000D_\n_x000D_\n_x000D_\n<!DOCTYPE html>_x00...     benign
# 26  <!DOCTYPE html>_x000D_\n<html class=" responsi...     benign
# 27  <!DOCTYPE html><html lang="en"><head><meta cha...     benign
# 28  <!DOCTYPE html>\n<html lang="en" xmlns:og="htt...     benign
# 29  \n<!DOCTYPE HTML>\n<html lang="ko-KR" xml:lang...     benign
# 30  <!DOCTYPE html>\n<html lang="en">\n<head>\n  <...     benign
# 31  <!DOCTYPE html>\n<html lang="pt-BR"> <head><ti...     benign
# 32  \n<!DOCTYPE HTML>\n\n<html ng-app="usr" class=...     benign
# 33  <!DOCTYPE html>\n<html lang="en" dir="ltr" dat...     benign
# 34  <!DOCTYPE html><html lang="en" itemscope="" it...     benign
# 35  \n\n\n    <!DOCTYPE HTML>\n    <html class="sp...     benign
# 36  <!doctype html>\n<html lang="en"><head><meta h...     benign
# 37  \n\n\n\t<!DOCTYPE html>\n\t<html class="no-js"...     benign
# 38  _x000D_\n<!DOCTYPE HTML>_x000D_\n<html>_x000D_...     benign
# 39  <!DOCTYPE html>\n<html>\n\n<head>\n  <title>Bu...     benign

# %% [markdown]
# ### <b>Q2. html 에서 \<script>...\</script> 길이 계산</b>
# ---
# - BeautifulSoup으로 html소스를 python 객체로 변환
# - 함수로 구현하기
# - float으로 return 받기

# %%
#html 공백수 카운트 함수
def html_script_characters(soup):
    # soup > script
    html_len = str(soup.script)
    return float(len(html_len.replace(' ', '')))

# %%
from bs4 import BeautifulSoup
script_len = []

for index, row in df.iterrows():
    soup = BeautifulSoup(row.html_code, 'html.parser')
    script_len.append(html_script_characters(soup))

df['html_script_characters'] = script_len

# %% [markdown]
# ### <b>Q3. html에서 공백 수 계산</b>
# ---
# - BeautifulSoup으로 html소스를 python 객체로 변환
# - 함수로 구현하기
# - float으로 return 받기

# %%
def html_num_whitespace(soup):
    try:
        # soup > body > text > count
        NullCount = soup.body.text.count(' ')
        return float(NullCount)
    except:
        return 0.0

# %%
num_whitespace = []

for index, row in df.iterrows():
    soup = BeautifulSoup(row.html_code, 'html.parser')
    num_whitespace.append(html_num_whitespace(soup))

df['html_num_whitespace'] = num_whitespace

# %% [markdown]
# ### <b>Q4. html 에서 body 길이 계산</b>
# ---
# - BeautifulSoup으로 html소스를 python 객체로 변환
# - 함수로 구현하기
# - float으로 return 받기

# %%
def html_num_characters(soup):
    try:
        #soup > body > text
        bodyLen = len(      )
        return float(bodyLen)
    except:
        return 0.0

# %%
html_body = []

for index, row in df.iterrows():
    soup = BeautifulSoup(row.html_code, 'html.parser')
    html_body.append(html_num_characters(soup))

df['html_body_len'] = html_body

# %%
df.describe()
# Out:
#        html_script_characters  html_num_whitespace  html_body_len
# count               40.000000             40.00000           40.0
# mean               886.700000            307.65000            0.0
# std               1767.449694            900.94536            0.0
# min                  4.000000              0.00000            0.0
# 25%                109.750000              0.00000            0.0
# 50%                246.000000              6.00000            0.0
# 75%                633.500000            125.25000            0.0
# max               8871.000000           4166.00000            0.0

# %% [markdown]
# ### <b> Q5. script 에서 src, href 속성을 가진 태그수</b>
# 1. BeautifulSoup으로 html소스를 python 객체로 변환
# 2. 함수로 구현하기
# 3. float으로 return 받기

# %%
def html_link_in_script(soup):
    numOfLinks = len(soup.findAll('script', {"src": True}))
    numOfLinks += len(soup.findAll('script', {"href": True}))
    return float(numOfLinks)

# %%
html_script_link_num = []

for index, row in df.iterrows():
    soup = BeautifulSoup(row.html_code, 'html.parser')
    html_script_link_num.append(html_link_in_script(soup))

df['html_script_link_num'] = html_script_link_num

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# ### <b>Q1. 중복 데이터 제거</b>
# ---
#  - 중복된 행데이터 삭제

# %%
train_df = pd.read_csv('TrainData.csv',delimiter=',')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6108 entries, 0 to 6107
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 6108 non-null   int64
#  1   url_len                    6108 non-null   int64
#  2   url_num_hyphens_dom        6108 non-null   int64
#  3   url_num_dom_token          6105 non-null   float64
#  4   url_path_len               6107 non-null   float64
#  5   url_filename_len           6108 non-null   int64
#  6   url_longest_dom_token_len  6108 non-null   int64
#  7   url_average_dom_token_len  6108 non-null   float64
#  8   url_tld                    6108 non-null   int64
#  9   url_domain_len             6105 non-null   float64
#  10  url_hostname_len           6108 non-null   int64
#  11  url_num_dots               6108 non-null   int64
#  12  url_num_underscores        6107 non-null   float64
#  13  url_num_equals             6107 non-null   float64
#  14  url_num_slashes            6107 non-null   float64
#  15  url_num_dash               6108 non-null   int64
#  16  url_num_semicolon          6108 non-null   int64
#  17  url_num_at                 6108 non-null   int64
#  18  url_num_percent            6108 non-null   int64
#  19  url_num_plus               6108 non-null   int64
#  20  url_query_len              6108 non-null   int64
#  21  url_num_query_para         6108 non-null   int64
#  22  url_ip_present             6108 non-null   int64
#  23  url_entropy                6108 non-null   float64
#  24  url_count_consonants       6108 non-null   int64
#  25  url_num_digits             6108 non-null   int64
#  26  url_chinese_present        6108 non-null   int64
#  27  url_port                   6108 non-null   int64
#  28  html_num_tags('iframe')    6108 non-null   int64
#  29  html_num_tags('script')    6108 non-null   int64
#  30  html_num_tags('embed')     6108 non-null   int64
#  31  html_num_tags('object')    6108 non-null   int64
#  32  html_num_tags('div')       6108 non-null   int64
#  33  html_num_tags('head')      6108 non-null   int64
#  34  html_num_tags('body')      6108 non-null   int64
#  35  html_num_tags('form')      6108 non-null   int64
#  36  html_num_tags('a')         6108 non-null   int64
#  37  html_num_tags('small')     6108 non-null   int64
#  38  html_num_tags('span')      6108 non-null   int64
#  39  html_num_tags('input')     6108 non-null   int64
#  40  html_num_tags('applet')    6108 non-null   int64
#  41  html_num_tags('img')       6108 non-null   int64
#  42  html_num_tags('video')     6108 non-null   int64
#  43  html_num_tags('audio')     6108 non-null   int64
#  44  Result_v1                  6108 non-null   object
# dtypes: float64(8), int64(36), object(1)
# memory usage: 2.1+ MB

# %%
train_df.columns
# Out:
# Index(['Unnamed: 0', 'url_len', 'url_num_hyphens_dom', 'url_num_dom_token',
#        'url_path_len', 'url_filename_len', 'url_longest_dom_token_len',
#        'url_average_dom_token_len', 'url_tld', 'url_domain_len',
#        'url_hostname_len', 'url_num_dots', 'url_num_underscores',
#        'url_num_equals', 'url_num_slashes', 'url_num_dash',
#        'url_num_semicolon', 'url_num_at', 'url_num_percent', 'url_num_plus',
#        'url_query_len', 'url_num_query_para', 'url_ip_present', 'url_entropy',
#        'url_count_consonants', 'url_num_digits', 'url_chinese_present',
#        'url_port', 'html_num_tags('iframe')', 'html_num_tags('script')',
#        'html_num_tags('embed')', 'html_num_tags('object')',
#        'html_num_tags('div')', 'html_num_tags('head')',
#        'html_num_tags('body')', 'html_num_tags('form')', 'html_num_tags('a')',
#        'html_num_tags('small')', 'html_num_tags('span')',
#        'html_num_tags('input')', 'html_num_tags('applet')',
#        'html_num_tags('img')', 'html_num_tags('video')',
#        'html_num_tags('audio')', 'Result_v1'],
#       dtype='object')

# %%
# 중복 데이터 제거 : drop_duplicates()
train_df=train_df.drop_duplicates()

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6108 entries, 0 to 6107
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 6108 non-null   int64
#  1   url_len                    6108 non-null   int64
#  2   url_num_hyphens_dom        6108 non-null   int64
#  3   url_num_dom_token          6105 non-null   float64
#  4   url_path_len               6107 non-null   float64
#  5   url_filename_len           6108 non-null   int64
#  6   url_longest_dom_token_len  6108 non-null   int64
#  7   url_average_dom_token_len  6108 non-null   float64
#  8   url_tld                    6108 non-null   int64
#  9   url_domain_len             6105 non-null   float64
#  10  url_hostname_len           6108 non-null   int64
#  11  url_num_dots               6108 non-null   int64
#  12  url_num_underscores        6107 non-null   float64
#  13  url_num_equals             6107 non-null   float64
#  14  url_num_slashes            6107 non-null   float64
#  15  url_num_dash               6108 non-null   int64
#  16  url_num_semicolon          6108 non-null   int64
#  17  url_num_at                 6108 non-null   int64
#  18  url_num_percent            6108 non-null   int64
#  19  url_num_plus               6108 non-null   int64
#  20  url_query_len              6108 non-null   int64
#  21  url_num_query_para         6108 non-null   int64
#  22  url_ip_present             6108 non-null   int64
#  23  url_entropy                6108 non-null   float64
#  24  url_count_consonants       6108 non-null   int64
#  25  url_num_digits             6108 non-null   int64
#  26  url_chinese_present        6108 non-null   int64
#  27  url_port                   6108 non-null   int64
#  28  html_num_tags('iframe')    6108 non-null   int64
#  29  html_num_tags('script')    6108 non-null   int64
#  30  html_num_tags('embed')     6108 non-null   int64
#  31  html_num_tags('object')    6108 non-null   int64
#  32  html_num_tags('div')       6108 non-null   int64
#  33  html_num_tags('head')      6108 non-null   int64
#  34  html_num_tags('body')      6108 non-null   int64
#  35  html_num_tags('form')      6108 non-null   int64
#  36  html_num_tags('a')         6108 non-null   int64
#  37  html_num_tags('small')     6108 non-null   int64
#  38  html_num_tags('span')      6108 non-null   int64
#  39  html_num_tags('input')     6108 non-null   int64
#  40  html_num_tags('applet')    6108 non-null   int64
#  41  html_num_tags('img')       6108 non-null   int64
#  42  html_num_tags('video')     6108 non-null   int64
#  43  html_num_tags('audio')     6108 non-null   int64
#  44  Result_v1                  6108 non-null   object
# dtypes: float64(8), int64(36), object(1)
# memory usage: 2.1+ MB

# %% [markdown]
# #### <b>텍스트와 범주형 특성 처리 실습</b>
# ---

# %%
# unique() 유일한 값 확인
train_df['Result_v1'].unique()
# Out:
# array(['benign', 'malicious'], dtype=object)

# %%
# replace() 함수 사용
# 'benign'=1,'malicious'=-1 처리
train_df['Result_v1'].replace({'benign':1,'malicious':-1}, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19388\2602206954.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Result_v1'].replace({'benign':1,'malicious':-1}, inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_19388\2602206954.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train_df['Result_v1'].replace({'benign':1,'malicious':-1}, inplace=True)

# %%
train_df['Result_v1'].unique()
# Out:
# array([ 1, -1], dtype=int64)

# %%
train_df.columns
# Out:
# Index(['Unnamed: 0', 'url_len', 'url_num_hyphens_dom', 'url_num_dom_token',
#        'url_path_len', 'url_filename_len', 'url_longest_dom_token_len',
#        'url_average_dom_token_len', 'url_tld', 'url_domain_len',
#        'url_hostname_len', 'url_num_dots', 'url_num_underscores',
#        'url_num_equals', 'url_num_slashes', 'url_num_dash',
#        'url_num_semicolon', 'url_num_at', 'url_num_percent', 'url_num_plus',
#        'url_query_len', 'url_num_query_para', 'url_ip_present', 'url_entropy',
#        'url_count_consonants', 'url_num_digits', 'url_chinese_present',
#        'url_port', 'html_num_tags('iframe')', 'html_num_tags('script')',
#        'html_num_tags('embed')', 'html_num_tags('object')',
#        'html_num_tags('div')', 'html_num_tags('head')',
#        'html_num_tags('body')', 'html_num_tags('form')', 'html_num_tags('a')',
#        'html_num_tags('small')', 'html_num_tags('span')',
#        'html_num_tags('input')', 'html_num_tags('applet')',
#        'html_num_tags('img')', 'html_num_tags('video')',
#        'html_num_tags('audio')', 'Result_v1'],
#       dtype='object')

# %% [markdown]
# ### <b>Q3. 결측치 제거</b>
# ---

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6108 entries, 0 to 6107
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 6108 non-null   int64
#  1   url_len                    6108 non-null   int64
#  2   url_num_hyphens_dom        6108 non-null   int64
#  3   url_num_dom_token          6105 non-null   float64
#  4   url_path_len               6107 non-null   float64
#  5   url_filename_len           6108 non-null   int64
#  6   url_longest_dom_token_len  6108 non-null   int64
#  7   url_average_dom_token_len  6108 non-null   float64
#  8   url_tld                    6108 non-null   int64
#  9   url_domain_len             6105 non-null   float64
#  10  url_hostname_len           6108 non-null   int64
#  11  url_num_dots               6108 non-null   int64
#  12  url_num_underscores        6107 non-null   float64
#  13  url_num_equals             6107 non-null   float64
#  14  url_num_slashes            6107 non-null   float64
#  15  url_num_dash               6108 non-null   int64
#  16  url_num_semicolon          6108 non-null   int64
#  17  url_num_at                 6108 non-null   int64
#  18  url_num_percent            6108 non-null   int64
#  19  url_num_plus               6108 non-null   int64
#  20  url_query_len              6108 non-null   int64
#  21  url_num_query_para         6108 non-null   int64
#  22  url_ip_present             6108 non-null   int64
#  23  url_entropy                6108 non-null   float64
#  24  url_count_consonants       6108 non-null   int64
#  25  url_num_digits             6108 non-null   int64
#  26  url_chinese_present        6108 non-null   int64
#  27  url_port                   6108 non-null   int64
#  28  html_num_tags('iframe')    6108 non-null   int64
#  29  html_num_tags('script')    6108 non-null   int64
#  30  html_num_tags('embed')     6108 non-null   int64
#  31  html_num_tags('object')    6108 non-null   int64
#  32  html_num_tags('div')       6108 non-null   int64
#  33  html_num_tags('head')      6108 non-null   int64
#  34  html_num_tags('body')      6108 non-null   int64
#  35  html_num_tags('form')      6108 non-null   int64
#  36  html_num_tags('a')         6108 non-null   int64
#  37  html_num_tags('small')     6108 non-null   int64
#  38  html_num_tags('span')      6108 non-null   int64
#  39  html_num_tags('input')     6108 non-null   int64
#  40  html_num_tags('applet')    6108 non-null   int64
#  41  html_num_tags('img')       6108 non-null   int64
#  42  html_num_tags('video')     6108 non-null   int64
#  43  html_num_tags('audio')     6108 non-null   int64
#  44  Result_v1                  6108 non-null   int64
# dtypes: float64(8), int64(37)
# memory usage: 2.1 MB

# %%
# 결측치 제거
# dropna()

train_df = train_df.dropna(axis=0)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6099 entries, 0 to 6107
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 6099 non-null   int64
#  1   url_len                    6099 non-null   int64
#  2   url_num_hyphens_dom        6099 non-null   int64
#  3   url_num_dom_token          6099 non-null   float64
#  4   url_path_len               6099 non-null   float64
#  5   url_filename_len           6099 non-null   int64
#  6   url_longest_dom_token_len  6099 non-null   int64
#  7   url_average_dom_token_len  6099 non-null   float64
#  8   url_tld                    6099 non-null   int64
#  9   url_domain_len             6099 non-null   float64
#  10  url_hostname_len           6099 non-null   int64
#  11  url_num_dots               6099 non-null   int64
#  12  url_num_underscores        6099 non-null   float64
#  13  url_num_equals             6099 non-null   float64
#  14  url_num_slashes            6099 non-null   float64
#  15  url_num_dash               6099 non-null   int64
#  16  url_num_semicolon          6099 non-null   int64
#  17  url_num_at                 6099 non-null   int64
#  18  url_num_percent            6099 non-null   int64
#  19  url_num_plus               6099 non-null   int64
#  20  url_query_len              6099 non-null   int64
#  21  url_num_query_para         6099 non-null   int64
#  22  url_ip_present             6099 non-null   int64
#  23  url_entropy                6099 non-null   float64
#  24  url_count_consonants       6099 non-null   int64
#  25  url_num_digits             6099 non-null   int64
#  26  url_chinese_present        6099 non-null   int64
#  27  url_port                   6099 non-null   int64
#  28  html_num_tags('iframe')    6099 non-null   int64
#  29  html_num_tags('script')    6099 non-null   int64
#  30  html_num_tags('embed')     6099 non-null   int64
#  31  html_num_tags('object')    6099 non-null   int64
#  32  html_num_tags('div')       6099 non-null   int64
#  33  html_num_tags('head')      6099 non-null   int64
#  34  html_num_tags('body')      6099 non-null   int64
#  35  html_num_tags('form')      6099 non-null   int64
#  36  html_num_tags('a')         6099 non-null   int64
#  37  html_num_tags('small')     6099 non-null   int64
#  38  html_num_tags('span')      6099 non-null   int64
#  39  html_num_tags('input')     6099 non-null   int64
#  40  html_num_tags('applet')    6099 non-null   int64
#  41  html_num_tags('img')       6099 non-null   int64
#  42  html_num_tags('video')     6099 non-null   int64
#  43  html_num_tags('audio')     6099 non-null   int64
#  44  Result_v1                  6099 non-null   int64
# dtypes: float64(8), int64(37)
# memory usage: 2.1 MB

# %% [markdown]
# ### <b>Q4. 데이터 탐색을 통한 불필요한 칼럼 제거</b>
# ---
# - ex) 그래프, 데이터 상관관계 corr()등 활용
# - corr() 메서드 : 모든 특성 간의 표준 상관계수(피어슨의 R)
#   - 확률론과 통계학에서 두 변수간에 어떤 선형적 또는 비선형적 관계를 갖고 있는지를 분석하는 방법
#   - r 값은 X 와 Y 가 완전히 동일하면 +1, 전혀 다르면 0, 반대방향으로 완전히 동일 하면 –1
# - scatter 그래프를 활용한 데이터 분석

# %%
train_df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
train_df.corr()
# Out:
#                             url_len  url_num_hyphens_dom  url_num_dom_token  \
# url_len                    1.000000            -0.021590           0.003813
# url_num_hyphens_dom       -0.021590             1.000000          -0.110107
# url_num_dom_token          0.003813            -0.110107           1.000000
# url_path_len               0.925826            -0.100584          -0.004779
# url_filename_len           0.847399            -0.059089           0.020256
# url_longest_dom_token_len  0.008996             0.674715          -0.199791
# url_average_dom_token_len -0.006231             0.658653          -0.381486
# url_tld                    0.065051             0.140738          -0.310944
# url_domain_len             0.018871             0.599516           0.244571
# url_hostname_len           0.019715             0.600409           0.236772
# url_num_dots               0.253388            -0.086805           0.494114
# url_num_underscores        0.332557            -0.062767           0.039110
# url_num_equals             0.327068            -0.003748          -0.060369
# url_num_slashes            0.345402            -0.166028          -0.079167
# url_num_dash               0.144251             0.581236          -0.079151
# url_num_semicolon          0.155895            -0.016339          -0.007442
# url_num_at                 0.083462            -0.021283          -0.028494
# url_num_percent            0.833704            -0.043418           0.005243
# url_num_plus               0.351144            -0.009613           0.001450
# url_query_len              0.373523             0.012099          -0.054572
# url_num_query_para         0.324448             0.006544          -0.062862
# url_ip_present            -0.056706            -0.127923           0.361105
# url_entropy                0.281241             0.076604           0.016646
# url_count_consonants       0.790095             0.022937          -0.023110
# url_num_digits             0.916848            -0.063868           0.020455
# url_chinese_present             NaN                  NaN                NaN
# url_port                   0.032756            -0.019159           0.040207
# html_num_tags('iframe')    0.035160            -0.020748           0.025076
# html_num_tags('script')   -0.024757            -0.114814           0.010601
# html_num_tags('embed')    -0.013653            -0.054304           0.014140
# html_num_tags('object')   -0.026371            -0.054175           0.039545
# html_num_tags('div')      -0.018466            -0.008408           0.000696
# html_num_tags('head')      0.049181             0.040287          -0.050781
# html_num_tags('body')      0.046116            -0.021999          -0.050804
# html_num_tags('form')     -0.023082             0.055574          -0.099625
# html_num_tags('a')        -0.023669            -0.038931           0.019123
# html_num_tags('small')    -0.009227            -0.020845          -0.011347
# html_num_tags('span')     -0.009228            -0.021775           0.005144
# html_num_tags('input')    -0.020522             0.128894          -0.056162
# html_num_tags('applet')         NaN                  NaN                NaN
# html_num_tags('img')      -0.027907            -0.002138           0.019001
# html_num_tags('video')    -0.031514            -0.026647          -0.028614
# html_num_tags('audio')    -0.009059            -0.004638          -0.008123
# Result_v1                 -0.016564            -0.363948           0.263194
#
#                            url_path_len  url_filename_len  \
# url_len                        0.925826          0.847399
# url_num_hyphens_dom           -0.100584         -0.059089
# url_num_dom_token             -0.004779          0.020256
# url_path_len                   1.000000          0.919136
# url_filename_len               0.919136          1.000000
# url_longest_dom_token_len     -0.103884         -0.063097
# url_average_dom_token_len     -0.117880         -0.077263
# url_tld                        0.034509          0.017312
# url_domain_len                -0.114367         -0.062970
# url_hostname_len              -0.113648         -0.063120
# url_num_dots                   0.170875          0.087563
# url_num_underscores            0.227722          0.207019
# url_num_equals                 0.030290         -0.005160
# url_num_slashes                0.330003          0.090245
# url_num_dash                   0.062686         -0.001991
# url_num_semicolon              0.000984         -0.007265
# url_num_at                     0.018513          0.005878
# url_num_percent                0.899189          0.897717
# url_num_plus                   0.289415          0.319097
# url_query_len                  0.014103         -0.010057
# url_num_query_para             0.014906         -0.011363
# url_ip_present                -0.032849         -0.028777
# url_entropy                    0.152888          0.047277
# url_count_consonants           0.592565          0.458865
# url_num_digits                 0.927552          0.903156
# url_chinese_present                 NaN               NaN
# url_port                       0.038047          0.044471
# html_num_tags('iframe')        0.048697          0.055449
# html_num_tags('script')        0.007339          0.013681
# html_num_tags('embed')        -0.005534         -0.023628
# html_num_tags('object')       -0.019016         -0.024987
# html_num_tags('div')          -0.012764         -0.004573
# html_num_tags('head')          0.051460          0.052127
# html_num_tags('body')         -0.001250         -0.020382
# html_num_tags('form')         -0.031817         -0.038819
# html_num_tags('a')            -0.012026         -0.005379
# html_num_tags('small')        -0.003277         -0.000835
# html_num_tags('span')         -0.002613         -0.000736
# html_num_tags('input')        -0.046493         -0.036296
# html_num_tags('applet')             NaN               NaN
# html_num_tags('img')          -0.013834         -0.004382
# html_num_tags('video')        -0.027699         -0.016023
# html_num_tags('audio')        -0.007481         -0.011768
# Result_v1                      0.093370          0.115191
#
#                            url_longest_dom_token_len  \
# url_len                                     0.008996
# url_num_hyphens_dom                         0.674715
# url_num_dom_token                          -0.199791
# url_path_len                               -0.103884
# url_filename_len                           -0.063097
# url_longest_dom_token_len                   1.000000
# url_average_dom_token_len                   0.943278
# url_tld                                     0.276790
# url_domain_len                              0.858700
# url_hostname_len                            0.860612
# url_num_dots                               -0.154192
# url_num_underscores                        -0.094093
# url_num_equals                              0.008583
# url_num_slashes                            -0.123483
# url_num_dash                                0.392454
# url_num_semicolon                          -0.019805
# url_num_at                                 -0.001035
# url_num_percent                            -0.054189
# url_num_plus                                0.010203
# url_query_len                               0.023772
# url_num_query_para                          0.019702
# url_ip_present                             -0.263973
# url_entropy                                 0.136140
# url_count_consonants                        0.096808
# url_num_digits                             -0.066097
# url_chinese_present                              NaN
# url_port                                   -0.024508
# html_num_tags('iframe')                    -0.030650
# html_num_tags('script')                    -0.114933
# html_num_tags('embed')                     -0.043168
# html_num_tags('object')                    -0.061084
# html_num_tags('div')                       -0.014885
# html_num_tags('head')                       0.031927
# html_num_tags('body')                       0.062158
# html_num_tags('form')                       0.065525
# html_num_tags('a')                         -0.056702
# html_num_tags('small')                     -0.022140
# html_num_tags('span')                      -0.030995
# html_num_tags('input')                      0.136603
# html_num_tags('applet')                          NaN
# html_num_tags('img')                       -0.057497
# html_num_tags('video')                     -0.011989
# html_num_tags('audio')                     -0.007122
# Result_v1                                  -0.517172
#
#                            url_average_dom_token_len   url_tld  \
# url_len                                    -0.006231  0.065051
# url_num_hyphens_dom                         0.658653  0.140738
# url_num_dom_token                          -0.381486 -0.310944
# url_path_len                               -0.117880  0.034509
# url_filename_len                           -0.077263  0.017312
# url_longest_dom_token_len                   0.943278  0.276790
# url_average_dom_token_len                   1.000000  0.290714
# url_tld                                     0.290714  1.000000
# url_domain_len                              0.764368  0.175183
# url_hostname_len                            0.766973  0.188197
# url_num_dots                               -0.249974 -0.135910
# url_num_underscores                        -0.106404 -0.020551
# url_num_equals                              0.038361  0.045756
# url_num_slashes                            -0.126509  0.066023
# url_num_dash                                0.382959  0.110988
# url_num_semicolon                          -0.011194 -0.014196
# url_num_at                                  0.004026  0.014612
# url_num_percent                            -0.067664  0.020526
# url_num_plus                                0.006458  0.013709
# url_query_len                               0.047481  0.035710
# url_num_query_para                          0.048729  0.039244
# url_ip_present                             -0.282946 -0.718053
# url_entropy                                 0.120720  0.162019
# url_count_consonants                        0.082430  0.150208
# url_num_digits                             -0.075762 -0.006273
# url_chinese_present                              NaN       NaN
# url_port                                   -0.023061 -0.073658
# html_num_tags('iframe')                    -0.033042  0.004741
# html_num_tags('script')                    -0.114278  0.041214
# html_num_tags('embed')                     -0.030277  0.005174
# html_num_tags('object')                    -0.055272 -0.049313
# html_num_tags('div')                       -0.007979  0.021719
# html_num_tags('head')                       0.038159  0.007433
# html_num_tags('body')                       0.060423  0.029203
# html_num_tags('form')                       0.085827  0.074663
# html_num_tags('a')                         -0.054155  0.021812
# html_num_tags('small')                     -0.023238  0.014698
# html_num_tags('span')                      -0.030013  0.015765
# html_num_tags('input')                      0.148569  0.073766
# html_num_tags('applet')                          NaN       NaN
# html_num_tags('img')                       -0.042696  0.004393
# html_num_tags('video')                     -0.007847 -0.016168
# html_num_tags('audio')                     -0.004567 -0.005388
# Result_v1                                  -0.539803 -0.206721
#
#                            url_domain_len  url_hostname_len  ...  \
# url_len                          0.018871          0.019715  ...
# url_num_hyphens_dom              0.599516          0.600409  ...
# url_num_dom_token                0.244571          0.236772  ...
# url_path_len                    -0.114367         -0.113648  ...
# url_filename_len                -0.062970         -0.063120  ...
# url_longest_dom_token_len        0.858700          0.860612  ...
# url_average_dom_token_len        0.764368          0.766973  ...
# url_tld                          0.175183          0.188197  ...
# url_domain_len                   1.000000          0.999061  ...
# url_hostname_len                 0.999061          1.000000  ...
# url_num_dots                     0.059242          0.056166  ...
# url_num_underscores             -0.082469         -0.082804  ...
# url_num_equals                   0.017601          0.018552  ...
# url_num_slashes                 -0.172463         -0.168414  ...
# url_num_dash                     0.343858          0.345344  ...
# url_num_semicolon               -0.015053         -0.014696  ...
# url_num_at                      -0.006315         -0.005920  ...
# url_num_percent                 -0.057102         -0.057032  ...
# url_num_plus                     0.015339          0.015516  ...
# url_query_len                    0.033333          0.034109  ...
# url_num_query_para               0.027508          0.028358  ...
# url_ip_present                  -0.157423         -0.174419  ...
# url_entropy                      0.160451          0.164424  ...
# url_count_consonants             0.106282          0.108823  ...
# url_num_digits                  -0.054069         -0.054507  ...
# url_chinese_present                   NaN               NaN  ...
# url_port                        -0.004238         -0.024200  ...
# html_num_tags('iframe')         -0.020697         -0.019957  ...
# html_num_tags('script')         -0.101378         -0.098804  ...
# html_num_tags('embed')          -0.012041         -0.011375  ...
# html_num_tags('object')         -0.031148         -0.033049  ...
# html_num_tags('div')            -0.002720         -0.001730  ...
# html_num_tags('head')            0.002894          0.002901  ...
# html_num_tags('body')            0.037640          0.037927  ...
# html_num_tags('form')            0.028735          0.031507  ...
# html_num_tags('a')              -0.037998         -0.036968  ...
# html_num_tags('small')          -0.027312         -0.026903  ...
# html_num_tags('span')           -0.024793         -0.024246  ...
# html_num_tags('input')           0.121214          0.122813  ...
# html_num_tags('applet')               NaN               NaN  ...
# html_num_tags('img')            -0.022369         -0.021090  ...
# html_num_tags('video')          -0.022319         -0.022212  ...
# html_num_tags('audio')          -0.003479         -0.004195  ...
# Result_v1                       -0.383350         -0.386960  ...
#
#                            html_num_tags('form')  html_num_tags('a')  \
# url_len                                -0.023082           -0.023669
# url_num_hyphens_dom                     0.055574           -0.038931
# url_num_dom_token                      -0.099625            0.019123
# url_path_len                           -0.031817           -0.012026
# url_filename_len                       -0.038819           -0.005379
# url_longest_dom_token_len               0.065525           -0.056702
# url_average_dom_token_len               0.085827           -0.054155
# url_tld                                 0.074663            0.021812
# url_domain_len                          0.028735           -0.037998
# url_hostname_len                        0.031507           -0.036968
# url_num_dots                           -0.077238           -0.035230
# url_num_underscores                    -0.073399           -0.006904
# url_num_equals                          0.003624           -0.026752
# url_num_slashes                         0.065168           -0.038722
# url_num_dash                            0.081693            0.068410
# url_num_semicolon                       0.010294           -0.010173
# url_num_at                             -0.011894           -0.011980
# url_num_percent                        -0.032595           -0.005702
# url_num_plus                           -0.000577           -0.004058
# url_query_len                           0.009379           -0.022490
# url_num_query_para                      0.003324           -0.024369
# url_ip_present                         -0.087663           -0.035485
# url_entropy                            -0.015997           -0.032620
# url_count_consonants                   -0.024412           -0.034364
# url_num_digits                         -0.022873           -0.013776
# url_chinese_present                          NaN                 NaN
# url_port                               -0.009327           -0.006813
# html_num_tags('iframe')                 0.137719            0.049900
# html_num_tags('script')                 0.266145            0.118783
# html_num_tags('embed')                 -0.028053            0.014111
# html_num_tags('object')                 0.002518            0.056888
# html_num_tags('div')                    0.138376            0.709659
# html_num_tags('head')                   0.035630            0.005387
# html_num_tags('body')                   0.025831           -0.008576
# html_num_tags('form')                   1.000000            0.098003
# html_num_tags('a')                      0.098003            1.000000
# html_num_tags('small')                  0.040097            0.026975
# html_num_tags('span')                   0.052905            0.712500
# html_num_tags('input')                  0.782866            0.045192
# html_num_tags('applet')                      NaN                 NaN
# html_num_tags('img')                    0.132080            0.270845
# html_num_tags('video')                  0.051463            0.038020
# html_num_tags('audio')                  0.101592            0.023789
# Result_v1                              -0.131112            0.123462
#
#                            html_num_tags('small')  html_num_tags('span')  \
# url_len                                 -0.009227              -0.009228
# url_num_hyphens_dom                     -0.020845              -0.021775
# url_num_dom_token                       -0.011347               0.005144
# url_path_len                            -0.003277              -0.002613
# url_filename_len                        -0.000835              -0.000736
# url_longest_dom_token_len               -0.022140              -0.030995
# url_average_dom_token_len               -0.023238              -0.030013
# url_tld                                  0.014698               0.015765
# url_domain_len                          -0.027312              -0.024793
# url_hostname_len                        -0.026903              -0.024246
# url_num_dots                            -0.017326              -0.021048
# url_num_underscores                     -0.010317              -0.001187
# url_num_equals                          -0.009908              -0.012320
# url_num_slashes                         -0.001086              -0.021593
# url_num_dash                            -0.012514               0.055933
# url_num_semicolon                       -0.003287              -0.004198
# url_num_at                              -0.004523              -0.004079
# url_num_percent                          0.002897              -0.000447
# url_num_plus                            -0.002635              -0.002310
# url_query_len                           -0.008497              -0.011043
# url_num_query_para                      -0.008792              -0.010920
# url_ip_present                          -0.011709              -0.021928
# url_entropy                             -0.043361              -0.024096
# url_count_consonants                    -0.019887              -0.014435
# url_num_digits                          -0.001542              -0.005836
# url_chinese_present                           NaN                    NaN
# url_port                                -0.002432              -0.003265
# html_num_tags('iframe')                  0.057903               0.026975
# html_num_tags('script')                  0.037143               0.069483
# html_num_tags('embed')                  -0.006080              -0.004328
# html_num_tags('object')                  0.027315               0.026273
# html_num_tags('div')                     0.030039               0.597288
# html_num_tags('head')                    0.004086               0.007274
# html_num_tags('body')                   -0.002105              -0.005733
# html_num_tags('form')                    0.040097               0.052905
# html_num_tags('a')                       0.026975               0.712500
# html_num_tags('small')                   1.000000               0.023977
# html_num_tags('span')                    0.023977               1.000000
# html_num_tags('input')                   0.026188               0.047760
# html_num_tags('applet')                       NaN                    NaN
# html_num_tags('img')                     0.077413               0.082330
# html_num_tags('video')                   0.024893               0.019658
# html_num_tags('audio')                   0.026410               0.002741
# Result_v1                                0.022100               0.056352
#
#                            html_num_tags('input')  html_num_tags('applet')  \
# url_len                                 -0.020522                      NaN
# url_num_hyphens_dom                      0.128894                      NaN
# url_num_dom_token                       -0.056162                      NaN
# url_path_len                            -0.046493                      NaN
# url_filename_len                        -0.036296                      NaN
# url_longest_dom_token_len                0.136603                      NaN
# url_average_dom_token_len                0.148569                      NaN
# url_tld                                  0.073766                      NaN
# url_domain_len                           0.121214                      NaN
# url_hostname_len                         0.122813                      NaN
# url_num_dots                            -0.021750                      NaN
# url_num_underscores                     -0.061285                      NaN
# url_num_equals                           0.009989                      NaN
# url_num_slashes                         -0.007039                      NaN
# url_num_dash                             0.088525                      NaN
# url_num_semicolon                        0.001662                      NaN
# url_num_at                              -0.010350                      NaN
# url_num_percent                         -0.036197                      NaN
# url_num_plus                            -0.002508                      NaN
# url_query_len                            0.025234                      NaN
# url_num_query_para                       0.016541                      NaN
# url_ip_present                          -0.061485                      NaN
# url_entropy                              0.001589                      NaN
# url_count_consonants                     0.001526                      NaN
# url_num_digits                          -0.034106                      NaN
# url_chinese_present                           NaN                      NaN
# url_port                                 0.009025                      NaN
# html_num_tags('iframe')                  0.114138                      NaN
# html_num_tags('script')                  0.154841                      NaN
# html_num_tags('embed')                  -0.049194                      NaN
# html_num_tags('object')                 -0.028390                      NaN
# html_num_tags('div')                     0.099268                      NaN
# html_num_tags('head')                    0.022740                      NaN
# html_num_tags('body')                   -0.009955                      NaN
# html_num_tags('form')                    0.782866                      NaN
# html_num_tags('a')                       0.045192                      NaN
# html_num_tags('small')                   0.026188                      NaN
# html_num_tags('span')                    0.047760                      NaN
# html_num_tags('input')                   1.000000                      NaN
# html_num_tags('applet')                       NaN                      NaN
# html_num_tags('img')                     0.060936                      NaN
# html_num_tags('video')                  -0.003346                      NaN
# html_num_tags('audio')                   0.021515                      NaN
# Result_v1                               -0.210413                      NaN
#
#                            html_num_tags('img')  html_num_tags('video')  \
# url_len                               -0.027907               -0.031514
# url_num_hyphens_dom                   -0.002138               -0.026647
# url_num_dom_token                      0.019001               -0.028614
# url_path_len                          -0.013834               -0.027699
# url_filename_len                      -0.004382               -0.016023
# url_longest_dom_token_len             -0.057497               -0.011989
# url_average_dom_token_len             -0.042696               -0.007847
# url_tld                                0.004393               -0.016168
# url_domain_len                        -0.022369               -0.022319
# url_hostname_len                      -0.021090               -0.022212
# url_num_dots                          -0.045858               -0.045738
# url_num_underscores                    0.005198               -0.016746
# url_num_equals                        -0.039777               -0.012111
# url_num_slashes                       -0.065322               -0.057820
# url_num_dash                           0.027799               -0.032612
# url_num_semicolon                     -0.012765               -0.005937
# url_num_at                            -0.016262               -0.007100
# url_num_percent                       -0.000096               -0.009943
# url_num_plus                          -0.007738               -0.004137
# url_query_len                         -0.034440               -0.008652
# url_num_query_para                    -0.037282               -0.009555
# url_ip_present                        -0.029883               -0.016223
# url_entropy                           -0.024278               -0.075387
# url_count_consonants                  -0.034935               -0.039488
# url_num_digits                        -0.023075               -0.016760
# url_chinese_present                         NaN                     NaN
# url_port                              -0.008144               -0.003817
# html_num_tags('iframe')                0.097524               -0.001706
# html_num_tags('script')                0.141260                0.031392
# html_num_tags('embed')                 0.031280               -0.011906
# html_num_tags('object')                0.083687                0.358536
# html_num_tags('div')                   0.223185                0.041259
# html_num_tags('head')                 -0.000819               -0.000287
# html_num_tags('body')                  0.003348               -0.007339
# html_num_tags('form')                  0.132080                0.051463
# html_num_tags('a')                     0.270845                0.038020
# html_num_tags('small')                 0.077413                0.024893
# html_num_tags('span')                  0.082330                0.019658
# html_num_tags('input')                 0.060936               -0.003346
# html_num_tags('applet')                     NaN                     NaN
# html_num_tags('img')                   1.000000                0.076918
# html_num_tags('video')                 0.076918                1.000000
# html_num_tags('audio')                -0.000405                0.524413
# Result_v1                              0.149920                0.001736
#
#                            html_num_tags('audio')  Result_v1
# url_len                                 -0.009059  -0.016564
# url_num_hyphens_dom                     -0.004638  -0.363948
# url_num_dom_token                       -0.008123   0.263194
# url_path_len                            -0.007481   0.093370
# url_filename_len                        -0.011768   0.115191
# url_longest_dom_token_len               -0.007122  -0.517172
# url_average_dom_token_len               -0.004567  -0.539803
# url_tld                                 -0.005388  -0.206721
# url_domain_len                          -0.003479  -0.383350
# url_hostname_len                        -0.004195  -0.386960
# url_num_dots                            -0.024669   0.049225
# url_num_underscores                     -0.008996   0.114241
# url_num_equals                           0.001132  -0.192470
# url_num_slashes                         -0.006951  -0.157474
# url_num_dash                             0.009093  -0.195049
# url_num_semicolon                       -0.003628  -0.060768
# url_num_at                              -0.004338  -0.072670
# url_num_percent                         -0.007664   0.118113
# url_num_plus                            -0.002528  -0.002219
# url_query_len                           -0.004646  -0.166944
# url_num_query_para                      -0.005180  -0.178318
# url_ip_present                          -0.004540   0.083675
# url_entropy                             -0.026159  -0.169434
# url_count_consonants                    -0.008715  -0.149691
# url_num_digits                          -0.004800   0.077009
# url_chinese_present                           NaN        NaN
# url_port                                 0.066893   0.012192
# html_num_tags('iframe')                  0.008136   0.031671
# html_num_tags('script')                  0.026531   0.206241
# html_num_tags('embed')                  -0.007275   0.108915
# html_num_tags('object')                  0.376947   0.107646
# html_num_tags('div')                     0.009002   0.066817
# html_num_tags('head')                   -0.000175  -0.035663
# html_num_tags('body')                   -0.004484  -0.111351
# html_num_tags('form')                    0.101592  -0.131112
# html_num_tags('a')                       0.023789   0.123462
# html_num_tags('small')                   0.026410   0.022100
# html_num_tags('span')                    0.002741   0.056352
# html_num_tags('input')                   0.021515  -0.210413
# html_num_tags('applet')                       NaN        NaN
# html_num_tags('img')                    -0.000405   0.149920
# html_num_tags('video')                   0.524413   0.001736
# html_num_tags('audio')                   1.000000   0.009203
# Result_v1                                0.009203   1.000000
#
# [44 rows x 44 columns]

# %%
train_df.corr()['Result_v1'].sort_values(ascending=False)
# Out:
# Result_v1                    1.000000
# url_num_dom_token            0.263194
# html_num_tags('script')      0.206241
# html_num_tags('img')         0.149920
# html_num_tags('a')           0.123462
# url_num_percent              0.118113
# url_filename_len             0.115191
# url_num_underscores          0.114241
# html_num_tags('embed')       0.108915
# html_num_tags('object')      0.107646
# url_path_len                 0.093370
# url_ip_present               0.083675
# url_num_digits               0.077009
# html_num_tags('div')         0.066817
# html_num_tags('span')        0.056352
# url_num_dots                 0.049225
# html_num_tags('iframe')      0.031671
# html_num_tags('small')       0.022100
# url_port                     0.012192
# html_num_tags('audio')       0.009203
# html_num_tags('video')       0.001736
# url_num_plus                -0.002219
# url_len                     -0.016564
# html_num_tags('head')       -0.035663
# url_num_semicolon           -0.060768
# url_num_at                  -0.072670
# html_num_tags('body')       -0.111351
# html_num_tags('form')       -0.131112
# url_count_consonants        -0.149691
# url_num_slashes             -0.157474
# url_query_len               -0.166944
# url_entropy                 -0.169434
# url_num_query_para          -0.178318
# url_num_equals              -0.192470
# url_num_dash                -0.195049
# url_tld                     -0.206721
# html_num_tags('input')      -0.210413
# url_num_hyphens_dom         -0.363948
# url_domain_len              -0.383350
# url_hostname_len            -0.386960
# url_longest_dom_token_len   -0.517172
# url_average_dom_token_len   -0.539803
# url_chinese_present               NaN
# html_num_tags('applet')           NaN
# Name: Result_v1, dtype: float64

# %% [markdown]
# #### <b>scatter 그래프를 활용한 데이터 분석 실습</b>
# ---

# %%
import matplotlib.pyplot as plt

# %%
# 1 = 'blue',-1 = 'red' 처리
train_df['color'] = train_df['Result_v1'].map({1:"blue", -1:"red"})

# %%
y_list = train_df.columns

for i in range(0, len(y_list)):
    train_df.plot(kind='scatter',x='Result_v1',y=y_list[i],s=30, c=train_df['color'])
    plt.title('Scatter Benign Malicious', fontsize=20)
    plt.xlabel('Result_v1')
    plt.ylabel(y_list[i])
    plt.show()

# %% [markdown]
# #### <b>불필요한 컬럼 제거</b>
# ---

# %%
train_df.drop(columns=["url_chinese_present","html_num_tags('applet')","color"],inplace=True)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6099 entries, 0 to 6107
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   url_len                    6099 non-null   int64
#  1   url_num_hyphens_dom        6099 non-null   int64
#  2   url_num_dom_token          6099 non-null   float64
#  3   url_path_len               6099 non-null   float64
#  4   url_filename_len           6099 non-null   int64
#  5   url_longest_dom_token_len  6099 non-null   int64
#  6   url_average_dom_token_len  6099 non-null   float64
#  7   url_tld                    6099 non-null   int64
#  8   url_domain_len             6099 non-null   float64
#  9   url_hostname_len           6099 non-null   int64
#  10  url_num_dots               6099 non-null   int64
#  11  url_num_underscores        6099 non-null   float64
#  12  url_num_equals             6099 non-null   float64
#  13  url_num_slashes            6099 non-null   float64
#  14  url_num_dash               6099 non-null   int64
#  15  url_num_semicolon          6099 non-null   int64
#  16  url_num_at                 6099 non-null   int64
#  17  url_num_percent            6099 non-null   int64
#  18  url_num_plus               6099 non-null   int64
#  19  url_query_len              6099 non-null   int64
#  20  url_num_query_para         6099 non-null   int64
#  21  url_ip_present             6099 non-null   int64
#  22  url_entropy                6099 non-null   float64
#  23  url_count_consonants       6099 non-null   int64
#  24  url_num_digits             6099 non-null   int64
#  25  url_port                   6099 non-null   int64
#  26  html_num_tags('iframe')    6099 non-null   int64
#  27  html_num_tags('script')    6099 non-null   int64
#  28  html_num_tags('embed')     6099 non-null   int64
#  29  html_num_tags('object')    6099 non-null   int64
#  30  html_num_tags('div')       6099 non-null   int64
#  31  html_num_tags('head')      6099 non-null   int64
#  32  html_num_tags('body')      6099 non-null   int64
#  33  html_num_tags('form')      6099 non-null   int64
#  34  html_num_tags('a')         6099 non-null   int64
#  35  html_num_tags('small')     6099 non-null   int64
#  36  html_num_tags('span')      6099 non-null   int64
#  37  html_num_tags('input')     6099 non-null   int64
#  38  html_num_tags('img')       6099 non-null   int64
#  39  html_num_tags('video')     6099 non-null   int64
#  40  html_num_tags('audio')     6099 non-null   int64
#  41  Result_v1                  6099 non-null   int64
# dtypes: float64(8), int64(34)
# memory usage: 2.0 MB

# %% [markdown]
# ## Q5. train_test_split을 이용하여, train_x, val_x, train_y, val_y로 데이터 분리
# ---
#
# - test_size = 0.3
# - random_state = 2021

# %%
from sklearn.model_selection import train_test_split

# %%
X = train_df.iloc[:,0:len(train_df.columns)-1].values
y = train_df.iloc[:,len(train_df.columns)-1].values

# %%
# train_test_split 사용
train_x, val_x, train_y, val_y = train_test_split(X, y,test_size=0.3,random_state=2021)

# %%
train_x.shape, val_x.shape, train_y.shape, val_y.shape
# Out:
# ((4269, 41), (1830, 41), (4269,), (1830,))

# %% [markdown]
# ### AI모델링

# %%
# %pip install tensorflow
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: tensorflow in c:\users\user\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\user\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\user\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\user\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\user\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### <b>Confusion Matrix 함수 정의</b>
# ---

# %% [markdown]
# - Confusion Matrix란?
#  - Training 을 통한 Prediction 성능을 측정하기 위해 예측 value와 실제 value를 비교하기 위한 표
#  - 참고 사이트 : https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html

# %%
from sklearn.metrics import classification_report as creport
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %%
def plot_confusion_matrix(ax, matrix, labels = ['malicious','benign'], title='Confusion matrix', fontsize=9):
    ax.set_xticks([x for x in range(len(labels))])
    ax.set_yticks([y for y in range(len(labels))])

    # Place labels on minor ticks
    ax.set_xticks([x + 0.5 for x in range(len(labels))], minor=True)
    ax.set_xticklabels(labels, rotation='90', fontsize=fontsize, minor=True)
    ax.set_yticks([y + 0.5 for y in range(len(labels))], minor=True)
    ax.set_yticklabels(labels[::-1], fontsize=fontsize, minor=True)

    # Hide major tick labels
    ax.tick_params(which='major', labelbottom='off', labelleft='off')

    # Finally, hide minor tick marks
    ax.tick_params(which='minor', width=0)

    # Plot heat map
    proportions = [1. * row / sum(row) for row in matrix]
    ax.pcolor(np.array(proportions[::-1]), cmap=plt.cm.Blues)

    # Plot counts as text
    for row in range(len(matrix)):
        for col in range(len(matrix[row])):
            confusion = matrix[::-1][row][col]
            if confusion != 0:
                ax.text(col + 0.5, row + 0.5, int(confusion),
                        fontsize=fontsize,
                        horizontalalignment='center',
                        verticalalignment='center')

    # Add finishing touches
    ax.grid(True, linestyle=':')
    ax.set_title(title, fontsize=fontsize)
    ax.set_xlabel('prediction', fontsize=fontsize)
    ax.set_ylabel('actual', fontsize=fontsize)

    plt.show()

# %% [markdown]
# ### <b>앙상블(Ensemble)</b>

# %% [markdown]
# ## Q3. Random Forest 모델

# %%
# 1. import
from sklearn.ensemble import RandomForestClassifier
# 2.선언
rfc = RandomForestClassifier()

# 3. fit()
rfc.fit(train_x,train_y)

# 3. predict()
rfc_pred = rfc.predict(val_x)

# train 및 val 데이터 정확도 확인 :score()
rfc.score(train_x,train_y), rfc.score(val_x, val_y)

# Confusion Matrix 확인
confusion = confusion_matrix(val_y, rfc_pred)
fig, ax = plt.subplots(figsize=(10,3))
plot_confusion_matrix(ax, confusion, fontsize=30)

# feature_importances_ 활용 Feature별 가중치 확인
plt.figure(figsize=(20,12))
plt.barh(y=train_df.columns[:-1],
        width = rfc.feature_importances_)
plt.show()

# %% [markdown]
# ### <b>RandomForest GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [ {'n_estimators':[30,40,50,60,100], 'max_depth':[30,40,50,60,100]}]

rfc = RandomForestClassifier()

rfc_grid = GridSearchCV(rfc, 
                        param_grid, # 
                        cv=2, 
                        scoring='accuracy', # Classification일때  'accuracy','f1' ...
                                            # Regression 일때 'neg_mean_squared_error','r2'...
                        n_jobs=-1,          
                        verbose=1           # Log 출력 Level 조정
                       )

rfc_grid.fit(train_x, train_y)

rfc_model = rfc_grid.best_estimator_

print('최적의 파라미터 값 : ', rfc_grid.best_params_)
print('최고의 점수 : ', rfc_grid.best_score_)
# Out:
# Fitting 2 folds for each of 25 candidates, totalling 50 fits
# 최적의 파라미터 값 :  {'max_depth': 50, 'n_estimators': 100}
# 최고의 점수 :  0.9686115726423314

# %%
rfc_grid_pred = rfc_model.predict(val_x)

# train 및 val 데이터 정확도
rfc_model.score(train_x, train_y), rfc_model.score(val_x, val_y)
# Out:
# (1.0, 0.9688524590163935)

# %%
#Confusion Matrix
confusion = confusion_matrix(val_y, rfc_grid_pred)
fig, ax = plt.subplots(figsize=(10,3))
plot_confusion_matrix(ax, confusion, fontsize=30)

# %%
# feature_importances_ 활용 Feature별 가중치 확인
plt.figure(figsize=(20,12))
plt.barh(y=train_df.columns[:-1],
        width = rfc_model.feature_importances_)
plt.show()

# %%
train_df.columns
# Out:
# Index(['url_len', 'url_num_hyphens_dom', 'url_num_dom_token', 'url_path_len',
#        'url_filename_len', 'url_longest_dom_token_len',
#        'url_average_dom_token_len', 'url_tld', 'url_domain_len',
#        'url_hostname_len', 'url_num_dots', 'url_num_underscores',
#        'url_num_equals', 'url_num_slashes', 'url_num_dash',
#        'url_num_semicolon', 'url_num_at', 'url_num_percent', 'url_num_plus',
#        'url_query_len', 'url_num_query_para', 'url_ip_present', 'url_entropy',
#        'url_count_consonants', 'url_num_digits', 'url_port',
#        'html_num_tags('iframe')', 'html_num_tags('script')',
#        'html_num_tags('embed')', 'html_num_tags('object')',
#        'html_num_tags('div')', 'html_num_tags('head')',
#        'html_num_tags('body')', 'html_num_tags('form')', 'html_num_tags('a')',
#        'html_num_tags('small')', 'html_num_tags('span')',
#        'html_num_tags('input')', 'html_num_tags('img')',
#        'html_num_tags('video')', 'html_num_tags('audio')', 'Result_v1'],
#       dtype='object')

# %%
import joblib
#train_df.drop('Result_v1',axis=1,inplace=True)
# 학습 데이터에서 컬럼명 추출 (X가 DataFrame이어야 함)
feature_columns = train_df.columns.tolist()
print(len(feature_columns))
print(feature_columns)
joblib.dump(feature_columns, 'feature_columns.pkl')
# Out:
# 42
# ['url_len', 'url_num_hyphens_dom', 'url_num_dom_token', 'url_path_len', 'url_filename_len', 'url_longest_dom_token_len', 'url_average_dom_token_len', 'url_tld', 'url_domain_len', 'url_hostname_len', 'url_num_dots', 'url_num_underscores', 'url_num_equals', 'url_num_slashes', 'url_num_dash', 'url_num_semicolon', 'url_num_at', 'url_num_percent', 'url_num_plus', 'url_query_len', 'url_num_query_para', 'url_ip_present', 'url_entropy', 'url_count_consonants', 'url_num_digits', 'url_port', "html_num_tags('iframe')", "html_num_tags('script')", "html_num_tags('embed')", "html_num_tags('object')", "html_num_tags('div')", "html_num_tags('head')", "html_num_tags('body')", "html_num_tags('form')", "html_num_tags('a')", "html_num_tags('small')", "html_num_tags('span')", "html_num_tags('input')", "html_num_tags('img')", "html_num_tags('video')", "html_num_tags('audio')", 'Result_v1']
# ['feature_columns.pkl']

# %%
#모델 저장
joblib.dump(rfc_model,'best_ml_model.pkl')
# Out:
# ['best_ml_model.pkl']

# %% [markdown]
# ### 모델 시뮬

# %%
simul = np.array([[]])  # -1 ~ 1 사이로 변환된 타깃값을 제외한 입력값들이 들어가야함

# %%
import pandas as pd
import joblib

# 모델 및 피처 목록 불러오기
ml_model = joblib.load('best_ml_model.pkl')
model_features = joblib.load('feature_columns.pkl')  # 정확히 41개
model_features = [col for col in model_features if col != 'Result_v1']

# CSV 불러오기
df = pd.read_csv('Feature Website2 HTML Processed.csv')

# 라벨 컬럼 제거
for label_col in ['Unnamed: 0','Result_v1', 'repu',"html_num_tags('applet')"]:
    if label_col in df.columns:
        df = df.drop(columns=[label_col])


# 누락된 컬럼 0으로 추가
for col in model_features:
    if col not in df.columns:
        df[col] = 0

# 1. model_features에 없는 컬럼 찾기
extra_cols = [col for col in df.columns if col not in model_features]
# 2. 없애야 할 컬럼 출력
if extra_cols:
    print("다음 컬럼은 제거됩니다:", extra_cols)
    

# 불필요한 컬럼 제거 (model_features에 없는 컬럼)
df = df.drop(columns=extra_cols, axis=1)  # ✅ 정확한 순서로 41개 컬럼만 유지

# 샘플 선택
simul = df.sample(n=1, random_state=None)

# 디버깅용 출력
print(f"모델 기대 피처 수: {ml_model.n_features_in_}")
print(f"입력 샘플 피처 수: {simul.shape[1]}")

# 예측 수행
res = ml_model.predict_proba(simul)

# 결과 출력
print("예측 결과:", res[0])  # 1: 정상, -1: 피싱
print(res)
# Out:
# 다음 컬럼은 제거됩니다: ['url_chinese_present', 'url_has_https', 'url_has_ip_address', 'url_num_subdomains', 'url_has_suspicious_words', 'url_length_category', 'url_has_port_in_url', 'url_num_special_chars', 'url_num_params', 'url_num_fragments', 'url_starts_with_www', 'url_is_shortened', 'url_has_email']
# 모델 기대 피처 수: 41
# 입력 샘플 피처 수: 41
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19388\1632345755.py in ?()
#      37 print(f"모델 기대 피처 수: {ml_model.n_features_in_}")
#      38 print(f"입력 샘플 피처 수: {simul.shape[1]}")
#      39
#      40 # 예측 수행
# ---> 41 res = ml_model.predict_proba(simul)
#      42
#      43 # 결과 출력
#      44 print("예측 결과:", res[0])  # 1: 정상, -1: 피싱
#
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#     941             classes corresponds to that in the attribute :term:`classes_`.
#     942         """
#     943         check_is_fitted(self)
#     944         # Check data
# --> 945         X = self._validate_X_predict(X)
#     946
#     947         # Assign chunk of trees to jobs
#     948         n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#     633             ensure_all_finite = "allow-nan"
#     634         else:
#     635             ensure_all_finite = True
#     636
# --> 637         X = validate_data(
#     638             self,
#     639             X,
#     640             dtype=DTYPE,
#
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2950             out = y
#    2951         else:
#    2952             out = X, y
#    2953     elif not no_val_X and no_val_y:
# -> 2954         out = check_array(X, input_name="X", **check_params)
#    2955     elif no_val_X and not no_val_y:
#    2956         out = _check_y(y, **check_params)
#    2957     else:
#
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1050                         )
#    1051                     array = xp.astype(array, dtype, copy=False)
#    1052                 else:
#    1053                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1054             except ComplexWarning as complex_warning:
#    1055                 raise ValueError(
#    1056                     "Complex data not supported\n{}\n".format(array)
#    1057                 ) from complex_warning
#
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     753         # Use NumPy API to support order
#     754         if copy is True:
#     755             array = numpy.array(array, order=order, dtype=dtype)
#     756         else:
# --> 757             array = numpy.asarray(array, order=order, dtype=dtype)
#     758
#     759         # At this point array is a NumPy ndarray. We convert it to an array
#     760         # container that is consistent with the input's namespace.
#
# c:\Users\user\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2164             )
#    2165         values = self._values
#    2166         if copy is None:
#    2167             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2168             arr = np.asarray(values, dtype=dtype)
#    2169         else:
#    2170             arr = np.array(values, dtype=dtype, copy=copy)
#    2171
#
# ValueError: could not convert string to float: 'fr'
